# %%
import numpy as np
import pandas as pd
from gensim import models
from gensim import corpora
from gensim.models.keyedvectors import KeyedVectors
from gensim.models import Phrases
from gensim.models.fasttext import FastText
from gensim.models.wrappers.fasttext import FastText as FT_wrapper
from gensim.models.word2vec import LineSentence
from gensim.corpora import Dictionary
from nltk.tokenize import sent_tokenize, word_tokenize
from stop_words import get_stop_words
from random import shuffle
import time
import re
import pylab as pl
from ipywidgets import FloatProgress
from IPython import display
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
def rescue_code(function):
    import inspect
    get_ipython().set_next_input("".join(inspect.getsourcelines(function)[0]))

# %%
def get_database(w2v):
    # load the dataset and all the text data
    database = pd.read_csv("../input/InvestData_2017-Nov-22_0101.csv").iloc[:, [1, 6, 9]]
    raw_texts = []
    # preprocess all the text data and remove any row without any useful data, and segment each word
    drop_list = []
    for row in database.itertuples():
        if not type(row[1]) is str or (not type(row[2]) is str and not type(row[3]) is str):
            drop_list.append(row[0])
        else:
            for col in [2, 3]:
                real_col = col - 1
                text = row[col]
                if type(text) is str:
                    text = word_tokenize_string(text, w2v)
                    text = ' '.join(text)
                    database.iloc[row[0], real_col] = text
                    raw_texts.append(text)
    database.drop(drop_list, inplace=True)
    database = database.assign(similarity=np.zeros(len(database)))

    return database, raw_texts

def get_tfidf_and_dictionary(texts):
    # get dictionary of texts
    texts = [text.split() for text in texts]
    dictionary = corpora.Dictionary(texts)
    
    # get tfidf ranking model
    tokenized_texts = [dictionary.doc2bow(text) for text in texts]
    tfidf = models.TfidfModel(tokenized_texts)
    
    return tfidf, dictionary

def word_tokenize_string(text, w2v):
    stop_words = get_stop_words('en')
    text = text.replace('\r', ' ').replace('\n', ' ')
    text = re.sub(r"http\S+", "", text)
    text = [word for sent in sent_tokenize(text.lower()) for word in word_tokenize(sent) if not word in stop_words and word in w2v]
    return text

def update_similarity(w2v, dictionary, tfidf, input_text, database):
    # get input text vector
    input_text_vector = get_doc_vector(input_text, w2v, dictionary, tfidf)
    i = 0
    for row in database.itertuples():
        row_text_vector = get_doc_vector(row[2], w2v, dictionary, tfidf)
        similarity = input_text_vector.dot(row_text_vector)
        database.iloc[i, -1] = similarity
        i += 1
    database = database.sort_values(by='similarity', ascending=False)
    return database

def get_doc_vector(text, w2v, dictionary, tfidf):
    tokens = list(dictionary.token2id)
    # convert any unknown word to known word
    new_text = []
    for word in text.split():
        if word in tokens:
            new_text.append(word)
        elif word in w2v: # replace the unknow word with the most similar word in tokens of dictionary
            new_text.append(w2v.most_similar_to_given(word_list=tokens, w1=word))
    
    # start to calculate vector using tfidf weighted word vector sum
    # get tfidf weight
    tokenized_text = [dictionary.doc2bow(new_text)]
    tfidf_text = tfidf[tokenized_text][0]
    # sum weighted word vectors
    sum_vector = w2v['happy'] * 0 # get the size of the word vector
    for word_id, weight in tfidf_text:
        word = dictionary[word_id]
        sum_vector += w2v[word] * weight
    sum_vector /= np.sqrt(sum_vector.dot(sum_vector)) # normalize the vector
    
    return sum_vector

# %%
w2v = KeyedVectors.load_word2vec_format("../w2v/model/wiki-news-300d-1M.vec")
# w2v = KeyedVectors.load("../w2v/model/fasttext_w2v_vector_64")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-a1ac5b12cf33> in <module>()
# ----> 1 w2v = KeyedVectors.load_word2vec_format("../w2v/model/wiki-news-300d-1M.vec")
#       2 # w2v = KeyedVectors.load("../w2v/model/fasttext_w2v_vector_64")
#
# ~/anaconda3/envs/tensorflow/lib/python3.5/site-packages/gensim/models/keyedvectors.py in load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype)
#     244                     if len(parts) != vector_size + 1:
#     245                         raise ValueError("invalid vector on line %s (is this really the text format?)" % line_no)
# --> 246                     word, weights = parts[0], [REAL(x) for x in parts[1:]]
#     247                     add_word(word, weights)
#     248         if result.syn0.shape[0] != len(result.vocab):
#
# ~/anaconda3/envs/tensorflow/lib/python3.5/site-packages/gensim/models/keyedvectors.py in <listcomp>(.0)
#     244                     if len(parts) != vector_size + 1:
#     245                         raise ValueError("invalid vector on line %s (is this really the text format?)" % line_no)
# --> 246                     word, weights = parts[0], [REAL(x) for x in parts[1:]]
#     247                     add_word(word, weights)
#     248         if result.syn0.shape[0] != len(result.vocab):
#
# KeyboardInterrupt:

# %%
database, texts = get_database(w2v)
tfidf, dictionary = get_tfidf_and_dictionary(texts)

# %%
pd.read_csv("../input/InvestData_2017-Nov-22_0101.csv").iloc[:, :]
# Out:
#         No                                       Organisation  \
# 0      0.0                                             filler
# 1      1.0        The Africa Enterprise Challenge Fund (AECF)
# 2      2.0   Alliance for a green revolution in Africa (AGRA)
# 3      3.0                             Global Innovation Fund
# 4      4.0                                        Acumen Fund
# 5      5.0                                     Bamboo Finance
# 6      6.0                           African Development Fund
# 7      7.0                                      Willow Impact
# 8      8.0                  Vista Ventures Social Impact Fund
# 9      9.0                                 Grayghost ventures
# 10    10.0  Business/Partners Investing in Entrepreneurs (...
# 11    11.0                LGT Venture Philanthropy Foundation
# 12    12.0                                             Grofin
# 13    13.0                               Invested Development
# 14    14.0               Investisseurs &\r\nPartenaires (I&P)
# 15    15.0                                           Novastar
# 16    16.0                                         Oikocredit
# 17    17.0                          Persistent Energy Capital
# 18    18.0             Social Venture Capital\r\nFund (SOVEC)
# 19    19.0                                   Terra Bella Fund
# 20    20.0                    African Development Bank (AfDB)
# 21    21.0                                      CDC Group plc
# 22    22.0                     European Investment Bank (EIB)
# 23    23.0     Netherlands Development Finance Company  (FMO)
# 24    24.0                               Norwegian Investment
# 25    25.0                                Fund for Developing
# 26    26.0                                Countries (Norfund)
# 27    27.0                                           Proparco
# 28    28.0  The Swiss Investment Fund for Emerging Markets...
# 29    29.0            International Finance Corporation (IFC)
# ..     ...                                                ...
# 88    88.0                        Yunus Social Business (YSB)
# 89    89.0                                    The BiD Network
# 90    90.0                Dalberg Global Development Advisors
# 91    91.0                                  Enclude Solutions
# 92    92.0                                    Endeavor Global
# 93    93.0                                   Impact Amplifier
# 94    94.0                          LifeCo UnLtd South Africa
# 95    95.0                              Open Capital Advisors
# 96    96.0                                   Shell Foundation
# 97    97.0             Social Enterprise Academy South Africa
# 98    98.0                                        Technoserve
# 99    99.0                                  Bertha Centre for
# 100  100.0                              Innovation and Social
# 101  101.0                                   Entrepreneurship
# 102  102.0                                (Graduate School of
# 103  103.0                 Business, University of Cape Town)
# 104  104.0               Lagos Business School (LBS), Nigeria
# 105  105.0            Strathmore Business School (SBS), Kenya
# 106  106.0                       Aspen Network of Development
# 107  107.0                               Entrepreneurs (ANDE)
# 108  108.0             Global Impact Investing Network (GIIN)
# 109  109.0  Southern African Impact Investing Network (SAIIN)
# 110  110.0      Global Impact Investing Rating System (GIIRS)
# 111    NaN                                                NaN
# 112    3.0                                                NaN
# 113    1.0                                                NaN
# 114    NaN                                                NaN
# 115    NaN                                               guav
# 116    NaN               Global Alliance for Clean Cookstoves
# 117    NaN                  Draper Richards Kaplan Foundation
#
#                       Type_1                                   Type_2  Region  \
# 0                        NaN                                      NaN     NaN
# 1                        NaN                                      NaN  Africa
# 2                        NaN                                      NaN  Africa
# 3                        NaN                                      NaN  Africa
# 4                        NaN                                      NaN  Africa
# 5                        NaN                                      NaN  Africa
# 6                        NaN                                      NaN  Africa
# 7                        NaN                                      NaN  Africa
# 8                        NaN                                      NaN  Africa
# 9                        NaN                                      NaN  Africa
# 10                       NaN                                      NaN  Africa
# 11         Primary Investors                              Foundations  Africa
# 12                       NaN                                      NaN  Africa
# 13            Asset Managers                              Foundations  Africa
# 14                       NaN                                      NaN  Africa
# 15                       NaN                                      NaN  Africa
# 16                       NaN                                      NaN  Africa
# 17            Asset Managers                              Foundations  Africa
# 18                       NaN                                      NaN  Africa
# 19                       NaN                                      NaN  Africa
# 20         Primary Investors  Development Finance Institutions (DFIs)  Africa
# 21         Primary Investors  Development Finance Institutions (DFIs)  Africa
# 22         Primary Investors  Development Finance Institutions (DFIs)  Africa
# 23         Primary Investors  Development Finance Institutions (DFIs)  Africa
# 24         Primary Investors  Development Finance Institutions (DFIs)  Africa
# 25         Primary Investors  Development Finance Institutions (DFIs)  Africa
# 26         Primary Investors  Development Finance Institutions (DFIs)  Africa
# 27         Primary Investors  Development Finance Institutions (DFIs)  Africa
# 28         Primary Investors  Development Finance Institutions (DFIs)  Africa
# 29         Primary Investors  Development Finance Institutions (DFIs)  Africa
# ..                       ...                                      ...     ...
# 88   Sector Ecosystem Actors                             Accelerators  Africa
# 89   Sector Ecosystem Actors          Non-Financial Advisory Services  Africa
# 90   Sector Ecosystem Actors          Non-Financial Advisory Services  Africa
# 91   Sector Ecosystem Actors          Non-Financial Advisory Services  Africa
# 92   Sector Ecosystem Actors          Non-Financial Advisory Services  Africa
# 93   Sector Ecosystem Actors          Non-Financial Advisory Services  Africa
# 94   Sector Ecosystem Actors          Non-Financial Advisory Services  Africa
# 95   Sector Ecosystem Actors          Non-Financial Advisory Services  Africa
# 96   Sector Ecosystem Actors          Non-Financial Advisory Services  Africa
# 97   Sector Ecosystem Actors          Non-Financial Advisory Services  Africa
# 98   Sector Ecosystem Actors          Non-Financial Advisory Services  Africa
# 99   Sector Ecosystem Actors                                 Academic  Africa
# 100  Sector Ecosystem Actors                                 Academic  Africa
# 101  Sector Ecosystem Actors                                 Academic  Africa
# 102  Sector Ecosystem Actors                                 Academic  Africa
# 103  Sector Ecosystem Actors                                 Academic  Africa
# 104  Sector Ecosystem Actors                                 Academic  Africa
# 105  Sector Ecosystem Actors                                 Academic  Africa
# 106  Sector Ecosystem Actors                                 Networks  Africa
# 107  Sector Ecosystem Actors                                 Networks  Africa
# 108  Sector Ecosystem Actors                                 Networks  Africa
# 109  Sector Ecosystem Actors                                 Networks  Africa
# 110  Sector Ecosystem Actors                 Rating and Accreditation  Africa
# 111                      NaN                                      NaN    asia
# 112                      NaN                                      NaN     NaN
# 113                      NaN                                      NaN     NaN
# 114                      NaN                                      NaN     NaN
# 115                      NaN                                      NaN     NaN
# 116                      NaN                            Clean cooking     NaN
# 117                      NaN                                      NaN     NaN
#
#                                                Website  \
# 0                                                  NaN
# 1                           http://www.aecfafrica.org/
# 2                              http://agra.org/grants/
# 3                     http://www.globalinnovation.fund
# 4                                   http://acumen.org/
# 5                             http://www.bamboocp.com/
# 6    http://www.afdb.org/en/about-us/corporate-info...
# 7                         http://www.willowimpact.com/
# 8                        http://www.vistaventures.com/
# 9         http://www.grayghostventures.com/indexa.html
# 10                      http://businesspartners.co.ke/
# 11                           https://www.lgtvp.com/en/
# 12                               http://www.grofin.com
# 13                     http://investeddevelopment.com/
# 14        http://www.ietp.com/en/content/entrepreneurs
# 15                    http://www.novastarventures.com/
# 16                     https://www.oikocredit.org.uk/t
# 17                        http://www.persistentnrg.com
# 18                                        www.sovec.nl
# 19   http://www.terraglobalcapital.com/terra-bella-...
# 20                                        www.afdb.org
# 21                                    www.cdcgroup.com
# 22                           http://www.eib.europa.eu/
# 23                                  http://www.fmo.nl/
# 24                              http://www.norfund.no/
# 25                                                 NaN
# 26                                                 NaN
# 27   http://www.proparco.fr/site/proparco/Accueil_P...
# 28                                http://www.sifem.ch/
# 29                                  http://www.ifc.org
# ..                                                 ...
# 88                                     www.yunussb.com
# 89                                  www.bidnetwork.org
# 90                              http://www.dalberg.com
# 91                            www.encludesolutions.com
# 92                            http://www.endeavor.org/
# 93                   http://www.impactamplifier.co.za/
# 94                    http://www.unltdsouthafrica.org/
# 95                     http://opencapitaladvisors.com/
# 96                             www.shellfoundation.org
# 97                          http://www.sea-africa.org/
# 98                          http://www.technoserve.org
# 99               http://www.gsb.uct. ac.za/s.asp?p=389
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
# 103                                                NaN
# 104                             http://www.lbs.edu.ng/
# 105                    http://www.sbs. strathmore.edu/
# 106                             www.aspeninstitute.org
# 107                                                NaN
# 108                             http://www.thegiin.org
# 109                            http://www.saiin.co.za/
# 110              http://b-analytics.net/ giirs-ratings
# 111                                                NaN
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                        http://cleancookstoves.org/
# 117                     https://www.drkfoundation.org/
#
#                                            Description  \
# 0                                                  NaN
# 1    The AECF is an Africa-based challenge fund tha...
# 2    AGRA aims to invest in projects that can have ...
# 3    A  government-sponsored non-profit fund in Lon...
# 4    A charity organisation providing funding for e...
# 5    Bamboo Finance is a commercial private equity ...
# 6    The ADF contributes to the promotion of econom...
# 7    An impact investment firm that manages and adv...
# 8    A California-based fund to provide education a...
# 9    Seeks to eliminate poverty and strengthen comm...
# 10   a specialist risk finance company that provide...
# 11   Seek to support both non-profit organizations ...
# 12   a pioneering development financier specialisin...
# 13   Invested Development is an impact investment m...
# 14   I&P is an impact investing group dedicated to ...
# 15   Novastar, based in Nairobi, is a venture catal...
# 16   Oikocredit is a worldwide cooperative\r\nand s...
# 17   PEC invests in and incubates businesses with a...
# 18   SOVEC is a fund that invests in local\r\nentre...
# 19   The Terra Bella Fund is\r\na frontier private ...
# 20   The AfDB is a multilateral DFI established to ...
# 21   CDC is the U.K.’s development finance institut...
# 22   The EIB is the bank of the European Union. It ...
# 23   FMO is a Netherlandsbased entrepreneurial deve...
# 24                            Norfund is the Norwegian
# 25   DFI. It invests in enterprises in low income c...
# 26                                                 NaN
# 27   Proparco is the French DFI. It invests in emer...
# 28   SIFEM is the DFI of Switzerland. Its mission i...
# 29   The IFC makes investments to inclusive busines...
# ..                                                 ...
# 88   Yunus Social Business is a social accelerator ...
# 89   The BiD Network aims to capacitate high-growth...
# 90   Dalberg is a strategic advisory firm that work...
# 91   Enclude is an advisory firm delivering capacit...
# 92   Endeavour Global is a consulting organization ...
# 93   Impact Amplifier is a consulting firm that wor...
# 94   LifeCo UnLtd South Africa is a nonprofit organ...
# 95   Open Capital provides advisory and management ...
# 96   The Shell Foundation is an independent, ventur...
# 97   The Social Enterprise Academy South Africa tai...
# 98   Technoserve is a nonprofit organization that d...
# 99   The Bertha Centre is an academic centre within...
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
# 103                                                NaN
# 104  LBS is a business school hosted by the Pan-Atl...
# 105  SBS is a business school in Nairobi, Kenya, th...
# 106  ANDE is a global network of organizations that...
# 107                                                NaN
# 108  The GIIN is a not-for-profit organization dedi...
# 109  SAIIN aims to promote the concept and practice...
# 110  GIIRS is a rating system for impact measuremen...
# 111                                                NaN
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116  The Global Alliance for Clean Cookstoves (Alli...
# 117  The Draper Richards Kaplan Foundation is a glo...
#
#                         Relevant_Products_and_Services  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11   Mainly loans and equity. Grants are only used ...
# 12                                                 NaN
# 13            Its BSP Fund is a seedstage equity fund.
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                    Equity and technical assistance.
# 18                                                 NaN
# 19                                                 NaN
# 20   The AfDB mobilises and allocates resources for...
# 21   ICDC provides capital in the form of both debt...
# 22   The EIB offers capital in the form of loans, v...
# 23   FMO offers finance in the form of:\r\n•       ...
# 24   Norfund offers capital primarily in the form o...
# 25                                                 NaN
# 26                                                 NaN
# 27   Proparco invests in the form of:\r\n•        E...
# 28   SIFEM invests via:\r\n•        Risk capital fu...
# 29   The IFC invests via:\r\n•        Loans\r\n•   ...
# ..                                                 ...
# 88   YSB identifies potential entrepreneurs, and of...
# 89   The BiD Network offers an entrepreneurs to acc...
# 90   Dalberg offers tailored services in each of th...
# 91   Enclude’s Capacity Solutions service assists f...
# 92   Endeavour Global offers strategy advice, mento...
# 93   Impact Amplifier assists sustainable social en...
# 94   LifeCo UnLtd offers a host of entrepreneur sup...
# 95   Open Capital provide intensive support to ente...
# 96   The Foundation works to identify market failur...
# 97   The organization offers introductory to advanc...
# 98   Technoserve works through:•        Capacity de...
# 99   The Bertha Centre focuses on Private sector an...
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
# 103                                                NaN
# 104  LBS is actively promoting impact investing and...
# 105  SBS actively promotes social entrepreneurship ...
# 106  ANDE offers a networking space for those worki...
# 107                                                NaN
# 108  The GIIN aims to build the infrastructure need...
# 109  SAIIN hosts an annual conference on impact inv...
# 110  The GIIRS rating system using a standard set o...
# 111                                                NaN
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
#
#                                      SectorsIndustries  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11   Multiple sectors including:\r\n•        Renewa...
# 12                                                 NaN
# 13   Multiple sectors, including:\r\n•        Mobil...
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                    • Clean energy\r
# 18                                                 NaN
# 19                                                 NaN
# 20   The AfDB operates in a wide number of sectors:...
# 21   CDC aims to invest where job creation can have...
# 22   The EIB’s activities focus on four core areas:...
# 23   FMO’s investments have a core focus on:\r\n•  ...
# 24   Norfund prioritises investment in the sectors of:
# 25                               •        Clean energy
# 26   •        Financial institutions\r\n•        Ag...
# 27   Proparco investments focus on:\r\n•        Ren...
# 28   Guidelines for SIFEM investments prioritise th...
# 29   A focus on inclusive businesses with a particu...
# ..                                                 ...
# 88   YSB’s current portfolio includes seven social ...
# 89   Multiple sectors, including: • Clean energy\r\...
# 90   Multiple sectors, including:\r\n•        Acces...
# 91                                                  \r
# 92                                                  \r
# 93                                                  \r
# 94                                          \r\n\r\n\r
# 95                                              \r\n\r
# 96   Its focus areas include improving: \r\n•      ...
# 97                                                  \r
# 98   Primarily agriculture and natural resources.\r...
# 99                                                 NaN
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
# 103                                                NaN
# 104                                                 \r
# 105                                                NaN
# 106                                                NaN
# 107                                                NaN
# 108                                                NaN
# 109                                                NaN
# 110                                                NaN
# 111                                                NaN
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116  Clean cooking technology (e.g. renewable bioma...
# 117                                 social enterprises
#
#                                        Funding_details  \
# 0                                                  NaN
# 1    1) Challenge Fund model where funding is award...
# 2    No much information provided - companies are u...
# 3    Amount: $230,000 max for pilot project\r\n* Pi...
# 4    Investment capital in the range of $0.25M-$3M,...
# 5                                                  NaN
# 6    Areas of funding: \r\nThe African Development ...
# 7                                                  NaN
# 8    Seek early stage companies that wish to raise ...
# 9    Stage: Early-stage venture capital \r\n\r\nLoc...
# 10   Structure financing solutions using shareholde...
# 11                                                 NaN
# 12   Investment Size: We invest between US$ 100K - ...
# 13   Not accepting funding applications currently, ...
# 14                                                 NaN
# 15                                                 NaN
# 16   Debt or equity financing typically worth € 3 -...
# 17                 Equity and technical\r\nassistance.
# 18                                 NA from the website
# 19                                 NA from the website
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 88                                                 NaN
# 89                                                 NaN
# 90                                                 NaN
# 91                                                 NaN
# 92                                                 NaN
# 93                                                 NaN
# 94                                                 NaN
# 95                                                 NaN
# 96                                                 NaN
# 97                                                 NaN
# 98                                                 NaN
# 99                                                 NaN
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
# 103                                                NaN
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
# 107                                                NaN
# 108                                                NaN
# 109                                                NaN
# 110                                                NaN
# 111                                                NaN
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116  Hosts a wide variety of funds. Check website f...
# 117  DRK investments are distributed twice a year o...
#
#                              Requirements__Eligibility  \
# 0                                                  NaN
# 1    Vary from competition to competition, but gene...
# 2                                                  NaN
# 3    More details: http://www.globalinnovation.fund...
# 4    Social responsibility and demonstrated sustain...
# 5    The company provides essential services afford...
# 6                                                  NaN
# 7    Geographic areas: Eastern Africa, the Middle E...
# 8    By early stage, we expect that applicant compa...
# 9    Our investment approach prioritizes social ven...
# 10   Your proposal will be assessed on the viabilit...
# 11   Criteria:\r\n1) Alignment with LGT Venture Phi...
# 12   Geography: We finance and support businesses t...
# 13   Multiple sectors,\r\nincluding:\r\n• Mobile/IC...
# 14                                                 NaN
# 15   Multiple sectors,\r\nincluding:\r\n• ICT\r\n• ...
# 16   Renewable Energy Ventures\r\n\r\nTypically, we...
# 17   Clean energy\r\n\r\n(not exactly specified on ...
# 18                                 NA from the website
# 19                                 NA from the website
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 88                                                 NaN
# 89                                                 NaN
# 90                                                 NaN
# 91                                                 NaN
# 92                                                 NaN
# 93                                                 NaN
# 94                                                 NaN
# 95                                                 NaN
# 96                                                 NaN
# 97                                                 NaN
# 98                                                 NaN
# 99                                                 NaN
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
# 103                                                NaN
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
# 107                                                NaN
# 108                                                NaN
# 109                                                NaN
# 110                                                NaN
# 111                                                NaN
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116  Vary from fund to fund, but generally:\r\n1.St...
# 117  Leaders tackling important social issues that ...
#
#                                               Examples  \
# 0                                                  NaN
# 1                                             M-Kopa\r
# 2                                                  NaN
# 3                                                  NaN
# 4    M-Kopa\r\n\r\nD.Light (Global company; african...
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                               M-Kopa
# 10                                                 NaN
# 11   Interested in energy sector but have not yet f...
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 88                                                 NaN
# 89                                                 NaN
# 90                                                 NaN
# 91                                                 NaN
# 92                                                 NaN
# 93                                                 NaN
# 94                                                 NaN
# 95                                                 NaN
# 96                                                 NaN
# 97                                                 NaN
# 98                                                 NaN
# 99                                                 NaN
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
# 103                                                NaN
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
# 107                                                NaN
# 108                                                NaN
# 109                                                NaN
# 110                                                NaN
# 111                                                NaN
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116  Impact Carbon, Eco-fuel, Sustainable Green Fue...
# 117                                                NaN
#
#                                            Application  \
# 0                                                  NaN
# 1    General Procedure\r\n\r\nBefore:\r\n1) Submit ...
# 2                                                  NaN
# 3    Accept applications all year round\r\n\r\n1) I...
# 4    Accept applications all year round\r\n\r\nMore...
# 5    Bamboo Finance Africa\r\n7th Floor, Purshottam...
# 6    East Africa Regional Resource Center (EARC)\r\...
# 7    http://www.willowimpact.com/contact-us/email-u...
# 8    Submit:\r\n1) Business plan (or equivalent)\r\...
# 9    Submit an executive summary to\r\ninfo@graygho...
# 10   Email the business plan to enquiries@businessp...
# 11   \r\nFill up the form below to get in touch\r\n...
# 12   Application Timeline: http://www.grofin.com/ou...
# 13                                                 NaN
# 14                                                 NaN
# 15   Not clear from the website. Need to leave a me...
# 16   Please contact our UK office if you think you ...
# 17                                       not specified
# 18                                 NA from the website
# 19                                 NA from the website
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 88                                                 NaN
# 89                                                 NaN
# 90                                                 NaN
# 91                                                 NaN
# 92                                                 NaN
# 93                                                 NaN
# 94                                                 NaN
# 95                                                 NaN
# 96                                                 NaN
# 97                                                 NaN
# 98                                                 NaN
# 99                                                 NaN
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
# 103                                                NaN
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
# 107                                                NaN
# 108                                                NaN
# 109                                                NaN
# 110                                                NaN
# 111                                                NaN
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
#
#                                                Contact  \
# 0                                                  NaN
# 1    The AECF Limited,\r\n\r\nWest End Towers, Kanj...
# 2    Nairobi\r\n\r\nTel: +254 (20) 3675 000 / +254 ...
# 3          http://www.globalinnovation.fund/contact-us
# 4           Do not accept contacts prior to submission
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9    Headquarters:\r\nGray Ghost Ventures\r\n2200 C...
# 10   Street Address\r\n1st Floor\r\nAfrica Re Centr...
# 11   LGT Venture Philanthropy\r\nHeadquarter:\r\nFä...
# 12   Block 9\r\nMedine Business Park\r\nBambous, 90...
# 13                        INFO@INVESTEDDEVELOPMENT.COM
# 14                                                 NaN
# 15   TELEPHONE\r\n+254 (0)20 388 2333 \r\n+254 723 ...
# 16   Postal Address:\r\n\r\nUnit 3, Hyde Park House...
# 17   North America - New York\r\n​\r\nChristopher A...
# 18   SOVEC Management BV\r\nDiemerzeedijk 27\r\n109...
# 19   For more information please contact:\r\n\r\nLe...
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 88                                                 NaN
# 89                                                 NaN
# 90                                                 NaN
# 91                                                 NaN
# 92                                                 NaN
# 93                                                 NaN
# 94                                                 NaN
# 95                                                 NaN
# 96                                                 NaN
# 97                                                 NaN
# 98                                                 NaN
# 99                                                 NaN
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
# 103                                                NaN
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
# 107                                                NaN
# 108                                                NaN
# 109                                                NaN
# 110                                                NaN
# 111                                                NaN
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116  1750 Pennsylvania Ave NW, Suite 300 Washington...
# 117  California Draper Richards Kaplan Foundation 1...
#
#      Additional_Information1  Additional_Information2  Additional_Information3
# 0                        NaN                      NaN                      NaN
# 1                        NaN                      NaN                      NaN
# 2                        NaN                      NaN                      NaN
# 3                        NaN                      NaN                      NaN
# 4                        NaN                      NaN                      NaN
# 5                        NaN                      NaN                      NaN
# 6                        NaN                      NaN                      NaN
# 7                        NaN                      NaN                      NaN
# 8                        NaN                      NaN                      NaN
# 9                        NaN                      NaN                      NaN
# 10                       NaN                      NaN                      NaN
# 11                       NaN                      NaN                      NaN
# 12                       NaN                      NaN                      NaN
# 13                       NaN                      NaN                      NaN
# 14                       NaN                      NaN                      NaN
# 15                       NaN                      NaN                      NaN
# 16                       NaN                      NaN                      NaN
# 17                       NaN                      NaN                      NaN
# 18                       NaN                      NaN                      NaN
# 19                       NaN                      NaN                      NaN
# 20                       NaN                      NaN                      NaN
# 21                       NaN                      NaN                      NaN
# 22                       NaN                      NaN                      NaN
# 23                       NaN                      NaN                      NaN
# 24                       NaN                      NaN                      NaN
# 25                       NaN                      NaN                      NaN
# 26                       NaN                      NaN                      NaN
# 27                       NaN                      NaN                      NaN
# 28                       NaN                      NaN                      NaN
# 29                       NaN                      NaN                      NaN
# ..                       ...                      ...                      ...
# 88                       NaN                      NaN                      NaN
# 89                       NaN                      NaN                      NaN
# 90                       NaN                      NaN                      NaN
# 91                       NaN                      NaN                      NaN
# 92                       NaN                      NaN                      NaN
# 93                       NaN                      NaN                      NaN
# 94                       NaN                      NaN                      NaN
# 95                       NaN                      NaN                      NaN
# 96                       NaN                      NaN                      NaN
# 97                       NaN                      NaN                      NaN
# 98                       NaN                      NaN                      NaN
# 99                       NaN                      NaN                      NaN
# 100                      NaN                      NaN                      NaN
# 101                      NaN                      NaN                      NaN
# 102                      NaN                      NaN                      NaN
# 103                      NaN                      NaN                      NaN
# 104                      NaN                      NaN                      NaN
# 105                      NaN                      NaN                      NaN
# 106                      NaN                      NaN                      NaN
# 107                      NaN                      NaN                      NaN
# 108                      NaN                      NaN                      NaN
# 109                      NaN                      NaN                      NaN
# 110                      NaN                      NaN                      NaN
# 111                      NaN                      NaN                      NaN
# 112                      NaN                      NaN                      NaN
# 113                      NaN                      NaN                      NaN
# 114                      NaN                      NaN                      NaN
# 115                      NaN                      NaN                      NaN
# 116                      NaN                      NaN                      NaN
# 117                      NaN                      NaN                      NaN
#
# [118 rows x 17 columns]

# %%
input_text = "new start up aiming at low income customers, dedicated in green energy"

# %%
search_output = update_similarity(w2v, dictionary, tfidf, input_text, database)
list(search_output.iloc[1, :])
# Out:
# ['Fund for Developing',
#  '. invests enterprises low income countries promote business development contribute economic growth poverty alleviation . ’ s geographic focus eastern southern africa , well selected countries asia central america . focuses supporting small medium sized companies .',
#  nan,
#  0.87590879201889038]

# %%
vec1 = get_doc_vector('a startup that dedicate to green energy', w2v, dictionary, tfidf)
vec2 = get_doc_vector('business regrading green energy', w2v, dictionary, tfidf)
vec3 = get_doc_vector('companies specificly support low-income people', w2v, dictionary, tfidf)

# %%
vec1.dot(vec2)
# Out:
# 0.83994347

# %%
vec1
# Out:
# array([-0.01663876, -0.00337446, -0.02395986, -0.04154515, -0.10667257,
#         0.01662513, -0.01009543,  0.06161033,  0.05003018, -0.06181473,
#        -0.02179295, -0.01145902, -0.01362746, -0.03405415,  0.00218448,
#         0.00767476, -0.01452028, -0.0018257 ,  0.07659619, -0.04767921,
#        -0.04837132, -0.02310556, -0.05546847, -0.00884663, -0.01575219,
#         0.00686825, -0.02110741,  0.02846674, -0.00410359,  0.0267566 ,
#         0.0219034 ,  0.01259031, -0.00153076,  0.0267643 ,  0.04200932,
#        -0.05939888,  0.02810077, -0.01088257,  0.02167377,  0.05022477,
#         0.00617732, -0.01705034,  0.04542316,  0.08962091, -0.01164754,
#         0.0392498 , -0.02558717, -0.0163672 ,  0.06803226, -0.01166763,
#         0.01418332,  0.04633227, -0.00154001,  0.00630221, -0.05789408,
#         0.02684514,  0.03213207,  0.02908244, -0.05910822,  0.01098826,
#        -0.04702628, -0.01257465,  0.02256784, -0.01471028], dtype=float32)

# %%
vec2
# Out:
# array([-0.01663876, -0.00337446, -0.02395986, -0.04154515, -0.10667257,
#         0.01662513, -0.01009543,  0.06161033,  0.05003018, -0.06181473,
#        -0.02179295, -0.01145902, -0.01362746, -0.03405415,  0.00218448,
#         0.00767476, -0.01452028, -0.0018257 ,  0.07659619, -0.04767921,
#        -0.04837132, -0.02310556, -0.05546847, -0.00884663, -0.01575219,
#         0.00686825, -0.02110741,  0.02846674, -0.00410359,  0.0267566 ,
#         0.0219034 ,  0.01259031, -0.00153076,  0.0267643 ,  0.04200932,
#        -0.05939888,  0.02810077, -0.01088257,  0.02167377,  0.05022477,
#         0.00617732, -0.01705034,  0.04542316,  0.08962091, -0.01164754,
#         0.0392498 , -0.02558717, -0.0163672 ,  0.06803226, -0.01166763,
#         0.01418332,  0.04633227, -0.00154001,  0.00630221, -0.05789408,
#         0.02684514,  0.03213207,  0.02908244, -0.05910822,  0.01098826,
#        -0.04702628, -0.01257465,  0.02256784, -0.01471028], dtype=float32)

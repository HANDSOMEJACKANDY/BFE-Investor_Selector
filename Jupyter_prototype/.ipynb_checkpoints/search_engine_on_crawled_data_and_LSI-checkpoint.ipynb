# %%
from bs4 import BeautifulSoup
import requests
import multiprocessing
import numpy as np
import pandas as pd
from gensim import models
from gensim import corpora
from gensim.models.keyedvectors import KeyedVectors
from gensim.models import Phrases
from gensim.models.fasttext import FastText
from gensim.models.wrappers.fasttext import FastText as FT_wrapper
from gensim.models.word2vec import LineSentence
from gensim.corpora import Dictionary
from fuzzywuzzy import fuzz
from nltk.tokenize import sent_tokenize, word_tokenize
from stop_words import get_stop_words
from random import shuffle
import time
import re
import pylab as pl
from ipywidgets import FloatProgress
from IPython import display
import matplotlib.pyplot as plt
# %matplotlib notebook
# Out:
# /home/yuze/.local/lib/python3.5/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
def get_urls_from_url(main_url):
    resp = requests.get(main_url)
    soup = BeautifulSoup(resp.content, 'html.parser')
    urls = []
    links = soup.find_all('a')
    for url in links:
        try:
            url = url.attrs['href']
            if len(url) > 5:
                urls.append(url)
        except:
            pass
    return urls

def get_texts_from_resp(resp):
    # parse the web response
    soup = BeautifulSoup(resp.content, 'html.parser')
    # find and filter texts
    print("These are texts under", resp.url)
    texts = soup.find_all('p')
    print("number of items grabed are", len(texts))
    texts = [text for text in texts if len(text.text) > 100]
    print("number of items after filtering", len(texts))
    # output texts
    for text in texts:
        #print(text.text)
        yield text.text

def url_is_valid(url):
    try:
        resp = requests.get(url, timeout=10)
        assert resp.status_code == 200
        return resp
    except:
        return False

def url_compare(url1, url2, thresh=70):
    """
    Based on the similarity between roots of two url, return whether these two url are smiliary or not
    """
    # extract pattern in () http(s)://()/???/???
    url1 = re.sub("(https?://)?", "", url1).split('/')[0]
    url2 = re.sub("(https?://)?", "", url2).split('/')[0]
    
    # find similarity between roots
    root_sim = fuzz.partial_ratio(url1, url2)
    
    if root_sim >= thresh:
        return True
    else:
        print(url1, " and ", url2, " may not be relevent")
        return False

def get_text_from_url_with_check(url, main_url):
    """
    The bottom function that extract text from url
    """
    # avoid url ends with .pdf
    if url.split(".")[-1] == "pdf":
        return []
    
    # check if url is valid
    resp = url_is_valid(url)
    # if the url is not valid, it is possible that it is in the form of 
    if not resp:
        if not "http" in url:
            url = main_url + url
            resp = url_is_valid(url)
            if not resp:
                print("url:", url, "invalid")
                return []
        else:
            print("url:", url, "invalid")
            return []
        
    # double check if the url is actually visited
    if resp.url != url: # meaning its redirected, which means an error happened
        # in many cases, the redirection is due to website has prefix https instead of http
        url = url[:4] + 's' + url[4:]
        resp = url_is_valid(url)
        if resp:
            if resp.url == url:
                print('try succeeded')
        else:
            return []
        
    # check if url is the child or sibling of main_url
    # sometimes, the url is directed to same irrelevent sites such as www.twitter.com etc.
    if not url_compare(main_url, resp.url):
        return []
    
    # get text from url
    text_data = []
    for text in get_texts_from_resp(resp):
        text_data.append(text)
    return text_data

def get_text_from_url_and_its_children(main_url):
    """
    Parallalize the text extraction process from given main url
    """
    # preprocess main url
    # remove space in url
    main_url = main_url.replace(" ", "")
    # force https:// prefix to the main url
    main_url = "https://" + re.sub("(https?://)?", "", main_url)
    # remove last "/" if there is one
    if main_url[-1] == "/":
        main_url = main_url[:-1]
    
    print("starting to crawl main url: ", main_url)
    
    # check validity of main_url
    resp = url_is_valid(main_url)
    if not resp:
        print("main_url: ", main_url, " is not valid")
        return False

    # grab all urls in this web page
    urls = [main_url]
    urls.extend(get_urls_from_url(main_url))
    # remove duplicated urls
    urls = list(set(urls)) 
    print("\n\nthese are the children links we crawled")
    print(urls, "\n")
    # grab all texts in each urls asynchronously
    # argmumentize urls
    urls = [(url, main_url) for url in urls]
    with multiprocessing.Pool(processes=24) as pool:
        text_data = pool.starmap(get_text_from_url_with_check, urls) 
    
    # collect output text data
    text_data = [text for text in text_data if len(text_data) > 0] # remove empty returns
    text_data = [text for text_list in text_data for text in text_list] # get list elements to str
    return " ".join(text_data)

# %%
database = pd.read_csv('../Examples/database.csv').iloc[:, [1, 5]]
database = database.dropna()
database['Crawled'] = np.vectorize(get_text_from_url_and_its_children)(database.iloc[:, 1])
# Out:
# starting to crawl main url:  https://www.aecfafrica.org
#
#
# these are the children links we crawled
# ['http://www.parioagency.com', '/portfolio/agribusiness', '\n\n\n\n\n/about-us/who-we-are\n\n\n', '/node/326', '/portfolio/competitions', '/the-aecf-management', '\n\n\n\n\n/portfolio/aecf_gender_lens_investment\n\n\n', 'mailto:info@aecfafrica.org', '/about-us/strategic-partners', '/about-us/The-AECF-Board', 'tel:+254203675394', '/about-us/our-history', '\n\n\n\n\n/about-us/funding-partners\n\n\n', '/about-us/funding-partners', '/work-with-us', 'tel:+254703033394', '/portfolio/aecf_gender_lens_investment', '/node/299', '/pt-pt', '/portfolio/renewable-energy/REACT-EEP', 'https://www.linkedin.com/company/africa-enterprise-challenge-fund', '\n\n\n\n\n/portfolio/agribusiness\n\n\n', '/portfolio/renewable-energy', '/media-centre/news', '/portfolio/renewable_energy/react_ssa', '\n\n\n\n\n/portfolio/renewable-energy\n\n\n', '/media-centre/videos', '/node/329', '/media-centre/blog', '/node/300', '\n\n\n\n\n/portfolio/renewable_energy/react_ssa\n\n\n', 'https://www.aecfafrica.org', '/portfolio/aecf-connect', '/knowledge-hub', 'https://www.facebook.com/AECFAfrica/', '/contact', '/portfolio/overview', '/impact', '/about-us/who-we-are', '/contact-us', 'https://twitter.com/AecfAfrica']
#
# url: https://www.aecfafrica.orgtel:+254203675394 invalid
# url: https://www.aecfafrica.orgtel:+254703033394 invalid
# url: https://www.aecfafrica.org
#
#
#
#
# /about-us/funding-partners
#
#
# url: https://www.aecfafrica.org
#
#
#
#
# /portfolio/agribusiness
#
#
# url: https://www.aecfafrica.org
#
#
#
#
# /portfolio/aecf_gender_lens_investment
#
#
# url: https://www.aecfafrica.org
#
#
#
#
# /about-us/who-we-are
#
#
#  invalid
#  invalid
#  invalid
#  invalid
# url: https://www.aecfafrica.org
#
#
#
#
# /portfolio/renewable-energy
#
#
#  invalid
# url: https://www.aecfafrica.org
#
#
#
#
# /portfolio/renewable_energy/react_ssa
#
#
#  invalid
# url: https://www.linkedin.com/company/africa-enterprise-challenge-fund invalid
# These are texts under https://www.aecfafrica.org/portfolio/competitions
# number of items grabed are 45
# number of items after filtering 28
# These are texts under https://www.aecfafrica.org/media-centre/news
# number of items grabed are 39
# number of items after filtering 14
# These are texts under https://www.aecfafrica.org/portfolio/agribusiness
# number of items grabed are 9
# number of items after filtering 6
# These are texts under https://www.aecfafrica.org/node/326
# number of items grabed are 2
# number of items after filtering 0
# These are texts under https://www.aecfafrica.org/about-us/funding-partners
# number of items grabed are 19
# number of items after filtering 10
# These are texts under https://www.aecfafrica.org/media-centre/videos
# number of items grabed are 13
# number of items after filtering 0
# These are texts under https://www.aecfafrica.org/portfolio/renewable_energy/react_ssa
# number of items grabed are 20
# number of items after filtering 11
# These are texts under https://www.aecfafrica.org/node/299
# number of items grabed are 2
# number of items after filtering 0
# These are texts under https://www.aecfafrica.org/about-us/our-history
# These are texts under https://www.aecfafrica.org/node/300
# number of items grabed are 12
# number of items grabed are 2
# number of items after filtering 8
# number of items after filtering 0
# These are texts under https://www.aecfafrica.org/portfolio/renewable-energy/REACT-EEP
# These are texts under https://www.aecfafrica.org/work-with-us
# number of items grabed are 16
# These are texts under https://www.aecfafrica.org/portfolio/aecf_gender_lens_investment
# number of items after filtering 6
# These are texts under https://www.aecfafrica.org/the-aecf-management
# number of items grabed are 13
# number of items grabed are 18
# number of items after filtering 6
# number of items after filtering 5
# number of items grabed are 15
# number of items after filtering 11
# These are texts under https://www.aecfafrica.org/media-centre/blog
# number of items grabed are 6
# number of items after filtering 0
# These are texts under https://www.aecfafrica.org/about-us/strategic-partners
# These are texts under https://www.aecfafrica.org/pt-pt
# These are texts under https://www.aecfafrica.org/portfolio/renewable-energy
# number of items grabed are 6
# number of items after filtering 3
# number of items grabed are 8
# number of items grabed are 5
# number of items after filtering 3
# number of items after filtering 2
# These are texts under https://www.aecfafrica.org/about-us/The-AECF-Board
# number of items grabed are 29
# number of items after filtering 27
# These are texts under https://www.aecfafrica.org/node/329
# These are texts under https://www.aecfafrica.org/portfolio/aecf-connect
# number of items grabed are 8
# number of items grabed are 3
# number of items after filtering 5
# number of items after filtering 0
# These are texts under https://www.aecfafrica.org/portfolio/overview
# number of items grabed are 1
# number of items after filtering 0
# These are texts under https://www.aecfafrica.org/knowledge-hub
# number of items grabed are 7
# number of items after filtering 4
# These are texts under https://www.aecfafrica.org/contact
# These are texts under https://www.aecfafrica.org/impact
# number of items grabed are 1
# number of items after filtering 0
# number of items grabed are 3
# number of items after filtering 1
# These are texts under https://www.aecfafrica.org/about-us/who-we-are
# number of items grabed are 6
# number of items after filtering 2
# These are texts under https://www.aecfafrica.org/contact-us
# number of items grabed are 4
# number of items after filtering 0
# www.aecfafrica.org  and  twitter.com  may not be relevent
# www.aecfafrica.org  and  www.facebook.com  may not be relevent
# url: http://www.parioagency.com invalid
# starting to crawl main url:  https://www.aecfafrica.org
#
#
# these are the children links we crawled
# ['http://www.parioagency.com', '/portfolio/agribusiness', '\n\n\n\n\n/about-us/who-we-are\n\n\n', '/node/326', '/portfolio/competitions', '/the-aecf-management', '\n\n\n\n\n/portfolio/aecf_gender_lens_investment\n\n\n', 'mailto:info@aecfafrica.org', '/about-us/strategic-partners', '/about-us/The-AECF-Board', 'tel:+254203675394', '/about-us/our-history', '\n\n\n\n\n/about-us/funding-partners\n\n\n', '/about-us/funding-partners', '/work-with-us', 'tel:+254703033394', '/portfolio/aecf_gender_lens_investment', '/node/299', '/pt-pt', '/portfolio/renewable-energy/REACT-EEP', 'https://www.linkedin.com/company/africa-enterprise-challenge-fund', '\n\n\n\n\n/portfolio/agribusiness\n\n\n', '/portfolio/renewable-energy', '/media-centre/news', '/portfolio/renewable_energy/react_ssa', '\n\n\n\n\n/portfolio/renewable-energy\n\n\n', '/media-centre/videos', '/node/329', '/media-centre/blog', '/node/300', '\n\n\n\n\n/portfolio/renewable_energy/react_ssa\n\n\n', 'https://www.aecfafrica.org', '/portfolio/aecf-connect', '/knowledge-hub', 'https://www.facebook.com/AECFAfrica/', '/contact', '/portfolio/overview', '/impact', '/about-us/who-we-are', '/contact-us', 'https://twitter.com/AecfAfrica']
#
# url: https://www.aecfafrica.orgtel:+254203675394 invalid
# url: https://www.aecfafrica.orgtel:+254703033394 invalid
# url: https://www.aecfafrica.org
#
#
#
#
# /portfolio/renewable-energy
#
#
# url: https://www.aecfafrica.org
#
#
#
#
# /about-us/who-we-are
#
#
#  invalid
#  invalid
# url: https://www.aecfafrica.org
#
#
#
#
# /portfolio/aecf_gender_lens_investment
#
#
# url: https://www.aecfafrica.org
#
#
#
#
# /portfolio/agribusiness
#
#
# url: https://www.aecfafrica.org
#
#
#
#
# /about-us/funding-partners
#
#
#  invalid
#  invalid
#  invalid
# url: https://www.aecfafrica.org
#
#
#
#
# /portfolio/renewable_energy/react_ssa
#
#
#  invalid
# url: https://www.linkedin.com/company/africa-enterprise-challenge-fund invalid
# These are texts under https://www.aecfafrica.org/portfolio/agribusiness
# number of items grabed are 9
# number of items after filtering 6
# These are texts under https://www.aecfafrica.org/node/326
# number of items grabed are 2
# number of items after filtering 0
# These are texts under https://www.aecfafrica.org/work-with-us
# number of items grabed are 13
# These are texts under https://www.aecfafrica.org/portfolio/renewable-energy/REACT-EEP
# number of items after filtering 6
# number of items grabed are 16
# number of items after filtering 6
# These are texts under https://www.aecfafrica.org/portfolio/aecf_gender_lens_investment
# number of items grabed are 18
# number of items after filtering 5
# These are texts under https://www.aecfafrica.org/portfolio/competitions
# These are texts under https://www.aecfafrica.org/media-centre/videos
# number of items grabed are 13
# number of items grabed are 45
# number of items after filtering 0
# number of items after filtering 28
# These are texts under https://www.aecfafrica.org/the-aecf-management
# These are texts under https://www.aecfafrica.org/about-us/strategic-partners
# number of items grabed are 15
# number of items grabed are 6
# number of items after filtering 11
# number of items after filtering 3
# These are texts under https://www.aecfafrica.org/node/329
# number of items grabed are 3
# number of items after filtering 0
# These are texts under https://www.aecfafrica.org/about-us/funding-partners
# number of items grabed are 19
# number of items after filtering 10
# These are texts under https://www.aecfafrica.org/pt-pt
# number of items grabed are 8
# number of items after filtering 3
# These are texts under https://www.aecfafrica.org/portfolio/renewable-energy
# number of items grabed are 5
# number of items after filtering 2
# These are texts under https://www.aecfafrica.org/node/299
# number of items grabed are 2
# number of items after filtering 0
# These are texts under https://www.aecfafrica.org/about-us/The-AECF-Board
# number of items grabed are 29
# number of items after filtering 27
# These are texts under https://www.aecfafrica.org/about-us/our-history
# number of items grabed are 12
# number of items after filtering 8
# These are texts under https://www.aecfafrica.org/media-centre/blog
# number of items grabed are 6
# number of items after filtering 0
# These are texts under https://www.aecfafrica.org/node/300
# These are texts under https://www.aecfafrica.org/impact
# number of items grabed are 2
# number of items grabed are 3
# number of items after filtering 0
# number of items after filtering 1
# These are texts under https://www.aecfafrica.org/knowledge-hub
# number of items grabed are 7
# number of items after filtering 4
# These are texts under https://www.aecfafrica.org/portfolio/renewable_energy/react_ssa
# number of items grabed are 20
# number of items after filtering 11
# These are texts under https://www.aecfafrica.org/portfolio/overview
# number of items grabed are 1
# number of items after filtering 0
# These are texts under https://www.aecfafrica.org/contact-us
# number of items grabed are 4
# number of items after filtering 0
# These are texts under https://www.aecfafrica.org/portfolio/aecf-connect
# number of items grabed are 8
# number of items after filtering 5
# These are texts under https://www.aecfafrica.org/contact
# number of items grabed are 1
# number of items after filtering 0
# These are texts under https://www.aecfafrica.org/about-us/who-we-are
# number of items grabed are 6
# number of items after filtering 2
# These are texts under https://www.aecfafrica.org/media-centre/news
# number of items grabed are 39
# number of items after filtering 14
# www.aecfafrica.org  and  twitter.com  may not be relevent
# www.aecfafrica.org  and  www.facebook.com  may not be relevent
# url: http://www.parioagency.com invalid
# starting to crawl main url:  https://agra.org/grants
#
#
# these are the children links we crawled
# ['https://web.facebook.com/africangreenrevolution/', 'https://agra.org/careers/vacancies/', 'https://agra.org/apply-for-a-grant/', 'https://agra.org/technical-documents/', 'https://twitter.com/AGRAAlliance', 'https://agra.org/where-we-work/', 'https://www.agrf.org/', 'https://agra.org/grants/', 'https://agra.org/wp-content/uploads/2018/10/AASR-2018.pdf', 'https://agra.org/', 'https://agra.org/wacci-calls-for-transformative-changes-of-agriculture-and-food-systems/', '/program-development-and-innovation', 'https://agra.org/program-development-and-innovation/', 'https://agra.org/wp-content/uploads/2018/08/AGRA-2017-Annual-Report0708201802.pdf', 'https://agra.org/annual-reports/', 'https://agra.org/partnership-for-inclusive-agricultural-transformation-in-africa-piata/', 'http://agrf.org/agra-2017-new-site/', 'https://agra.org/impact-magazine/', 'https://agra.org/news/', 'https://www.flickr.com/photos/130288136@N06', '/agra-2017-new-site/whistleblower-policy/', '/agra-2017-new-site/privacy-policy/', 'https://agra.org/faqs/', 'https://agra.org/policy-and-strategic-partnerships/', 'http://africafoodprize.org/', 'https://agra.org/wp-content/uploads/2018/02/IMPACT-Edition-1-January-March-2018-2.pdf', '/who-we-are', 'https://agra.org/harvest/', '/agra-2017-new-site/ip-policy/', 'https://agra.org/our-approach/', 'https://www.youtube.com/user/allianceforagreenrev', 'https://agra.org/who-we-are/', 'https://agra.org/country-support-and-delivery/', 'https://agra.org/jica-recognises-agra-for-role-in-initiative-that-has-doubled-africas-rice-yield-in-10-years/', 'https://agra.org/discover-8-pitch-agrihack-startups-who-won-the-2018-finals/', 'https://agra.org/progress-report/', 'https://agra.org/careers/consultancies/', '/agra-2017-new-site/contact/', 'https://agra.org/impact-stories-new/', 'https://agra.org/tenders/', 'https://agra.org/who-we-are-our-leadership/', 'https://agra.org/africas-big-philanthropy-agriculture-and-food-security-by-bbc/', 'https://agra.org/funding-partners/', 'https://agra.org/aasr2018/', 'https://agra.org/grants', 'mailto:rfcn@agra.org']
#
# agra.org  and  twitter.com  may not be relevent
# agra.org  and  www.flickr.com  may not be relevent
# url: http://agrf.org/agra-2017-new-site/ invalid
# agra.org  and  www.youtube.com  may not be relevent
# These are texts under https://agra.org/partnership-for-inclusive-agricultural-transformation-in-africa-piata/
# number of items grabed are 0
# number of items after filtering 0
# These are texts under https://agra.org/our-approach/
# number of items grabed are 5
# number of items after filtering 5
# These are texts under https://agra.org/annual-reports/
# number of items grabed are 0
# number of items after filtering 0
# These are texts under https://agra.org/faqs/
# number of items grabed are 0
# number of items after filtering 0
# url: https://agra.org/grants/agra-2017-new-site/whistleblower-policy/ invalid
# agra.org  and  www.africafoodprize.org  may not be relevent
# These are texts under https://agra.org/who-we-are/
# number of items grabed are 3
# number of items after filtering 3
# These are texts under https://agra.org/technical-documents/
# number of items grabed are 0
# number of items after filtering 0
# These are texts under https://agra.org/progress-report/
# number of items grabed are 0
# number of items after filtering 0
# These are texts under https://agra.org/apply-for-a-grant/
# number of items grabed are 1
# number of items after filtering 1
# These are texts under https://agra.org/grants/
# number of items grabed are 5
# number of items after filtering 4
# These are texts under https://agra.org/careers/vacancies/
# number of items grabed are 4
# number of items after filtering 4
# These are texts under https://agra.org/discover-8-pitch-agrihack-startups-who-won-the-2018-finals/
# number of items grabed are 67
# number of items after filtering 37
# url: https://agra.org/news/ invalid
# url: https://agra.org/ invalid
# url: https://agra.org/where-we-work/ invalid
# url: https://agra.org/grants/agra-2017-new-site/privacy-policy/ invalid
# url: https://agra.org/impact-magazine/ invalid
# url: https://agra.org/wacci-calls-for-transformative-changes-of-agriculture-and-food-systems/ invalid
# url: https://agra.org/program-development-and-innovation/ invalid
# url: https://agra.org/policy-and-strategic-partnerships/ invalid
# These are texts under https://agra.org/careers/consultancies/
# number of items grabed are 3
# number of items after filtering 3
# url: https://agra.org/grants/agra-2017-new-site/ip-policy/ invalid
# url: https://agra.org/aasr2018/ invalid
# url: https://agra.org/impact-stories-new/ invalid
# url: https://agra.org/tenders/ invalid
# url: https://agra.org/who-we-are-our-leadership/ invalid
# url: https://agra.org/grants invalid
# url: https://agra.org/jica-recognises-agra-for-role-in-initiative-that-has-doubled-africas-rice-yield-in-10-years/ invalid
# url: https://agra.org/grantsmailto:rfcn@agra.org invalid
# url: https://agra.org/country-support-and-delivery/ invalid
# url: https://agra.org/grants/program-development-and-innovation invalid
# url: https://agra.org/grants/agra-2017-new-site/contact/ invalid
# These are texts under https://agra.org/funding-partners/
# number of items grabed are 2
# number of items after filtering 2
# url: https://agra.org/africas-big-philanthropy-agriculture-and-food-security-by-bbc/ invalid
# starting to crawl main url:  https://www.globalinnovation.fund
# main_url:  https://www.globalinnovation.fund  is not valid
# starting to crawl main url:  https://acumen.org
#
#
# these are the children links we crawled
# ['https://www.plusacumen.org/courses/social-entrepreneurship-101', 'http://acumenideas.com/risky-business-3116c40826a1', 'https://medium.com/energy-impact-series/encouraging-children-to-do-their-homework-can-be-a-tough-task-at-the-best-of-times-285ce31440f9', 'https://acumen.org/fellowships/regions/', 'https://acumen.org/anti-corruption-policy/', 'https://www.plusacumen.org/courses/introduction-human-centered-design', 'https://briteweb.com/', 'https://twitter.com/acumen', 'https://www.classy.org/checkout/donation?eid=88993', 'https://acumen.org/privacy-policy/', 'https://acumen.org/companies/', 'https://acumen.org/regions/', 'https://acumen.org/partners/', 'https://www.facebook.com/acumenfund', 'https://acumen.org/blog/', 'http://acumen.org/partners/', 'https://acumen.org/work-with-us/', 'http://acumen.org/approach/', 'https://acumenideas.com/ethiopia-eaba071722b1', 'https://acumen.org/fellowships/', 'https://acumen.org/credits/', 'https://acumen.org/our-team/', 'https://www.plusacumen.org/courses/jonathan-greenblatt-fighting-hate-bias', 'https://acumen.org/reports/', 'http://acumen.org/work-with-us/', 'https://acumen.org', 'http://acumen.org/companies/', 'https://acumen.org/blog/sara-khurram/', 'https://acumen.org/about/', 'https://acumen.org/approach/', 'https://acumen.org/financial-overview/', 'https://acumen.org/companies/sectors/', 'https://acumen.org/seepeople', 'https://www.youtube.com/user/acumenfund', 'https://acumen.org/other-ways-to-give/', 'https://acumen.org/lean-data/', 'http://acumen.org/fellowships/', 'http://acumen.org/other-ways-to-give/', 'https://acumen.org/contact/', 'https://acumen.org/fellowships/program-details/', 'http://acumen.org/donate', 'https://acumen.org/manifesto/', 'https://acumenideas.com/too-broke-to-fix-7d1bba3f7db1', 'https://acumen.org/fellowships/faq/', 'https://www.classy.org/checkout/donation?eid=88993&recurring=1', 'https://www.plusacumen.org/courses/storytelling-change', 'http://acumen.org/lean-data/', 'https://acumen.org/fellowships/meet-the-fellows/', 'https://acumen.org/fellowships/apply/', 'https://acumen.org/terms-of-use/']
#
# url: https://briteweb.com/ invalid
# acumen.org  and  acumenideas.com  may not be relevent
# These are texts under https://www.plusacumen.org/courses/introduction-human-centered-design
# number of items grabed are 8
# These are texts under https://www.plusacumen.org/courses/social-entrepreneurship-101
# number of items after filtering 5
# number of items grabed are 6
# number of items after filtering 3
# These are texts under https://www.plusacumen.org/courses/jonathan-greenblatt-fighting-hate-bias
# number of items grabed are 14
# number of items after filtering 11
# acumen.org  and  twitter.com  may not be relevent
# These are texts under https://acumen.org/anti-corruption-policy/
# number of items grabed are 16
# number of items after filtering 5
# These are texts under https://acumen.org/regions/
# These are texts under https://acumen.org/fellowships/regions/
# number of items grabed are 22
# number of items grabed are 15
# number of items after filtering 7
# number of items after filtering 8
# acumen.org  and  medium.com  may not be relevent
# These are texts under https://acumen.org/work-with-us/
# number of items grabed are 10
# number of items after filtering 4
# These are texts under https://acumen.org/blog/
# number of items grabed are 33
# number of items after filtering 0
# These are texts under https://acumen.org/credits/
# number of items grabed are 14
# number of items after filtering 3
# These are texts under https://acumen.org/our-team/
# number of items grabed are 57
# number of items after filtering 0
# These are texts under https://acumen.org/reports/
# number of items grabed are 15
# number of items after filtering 7
# These are texts under https://acumen.org/companies/
# number of items grabed are 39
# number of items after filtering 0
# These are texts under https://acumen.org/privacy-policy/
# number of items grabed are 25
# number of items after filtering 18
# acumen.org  and  www.facebook.com  may not be relevent
# These are texts under https://acumen.org/partners/
# number of items grabed are 16
# number of items after filtering 7
# These are texts under https://acumen.org/fellowships/
# number of items grabed are 10
# number of items after filtering 3
# These are texts under https://acumen.org/blog/sara-khurram/
# number of items grabed are 34
# number of items after filtering 20
# These are texts under https://www.plusacumen.org/courses/storytelling-change
# number of items grabed are 7
# number of items after filtering 4
# These are texts under https://acumen.org/about/
# number of items grabed are 19
# number of items after filtering 7
# These are texts under https://acumen.org/approach/
# number of items grabed are 20
# number of items after filtering 6
# acumen.org  and  www.youtube.com  may not be relevent
# These are texts under https://acumen.org/financial-overview/
# number of items grabed are 36
# number of items after filtering 13
# These are texts under https://acumen.org/companies/sectors/
# number of items grabed are 28
# number of items after filtering 9
# These are texts under https://acumen.org/other-ways-to-give/
# number of items grabed are 20
# number of items after filtering 3
# These are texts under https://acumen.org/lean-data/
# number of items grabed are 35
# number of items after filtering 19
# These are texts under https://acumen.org/contact/
# number of items grabed are 34
# number of items after filtering 1
# These are texts under https://acumen.org/fellowships/program-details/
# number of items grabed are 23
# number of items after filtering 11
# These are texts under https://acumen.org/fellowships/faq/
# number of items grabed are 72
# number of items after filtering 32
# try succeeded
# These are texts under https://acumen.org/approach/
# number of items grabed are 20
# number of items after filtering 6
# try succeeded
# These are texts under https://acumen.org/work-with-us/
# number of items grabed are 10
# number of items after filtering 4
# These are texts under https://acumen.org/fellowships/meet-the-fellows/
# number of items grabed are 58
# number of items after filtering 2
# These are texts under https://acumen.org/manifesto/
# number of items grabed are 7
# number of items after filtering 5
# These are texts under https://acumen.org/fellowships/apply/
# number of items grabed are 6
# number of items after filtering 3
# try succeeded
# These are texts under https://acumen.org/terms-of-use/
# number of items grabed are 39
# number of items after filtering 34
# These are texts under https://acumen.org/companies/
# number of items grabed are 39
# number of items after filtering 0
# try succeeded
# These are texts under https://acumen.org/partners/
# number of items grabed are 16
# number of items after filtering 7
# try succeeded
# These are texts under https://acumen.org/other-ways-to-give/
# number of items grabed are 20
# number of items after filtering 3
# try succeeded
# These are texts under https://acumen.org/lean-data/
# number of items grabed are 35
# number of items after filtering 19
# try succeeded
# These are texts under https://acumen.org/fellowships/
# number of items grabed are 10
# number of items after filtering 3
# These are texts under https://donate.acumen.org/give/88993/#!/donation/checkout?
# number of items grabed are 0
# number of items after filtering 0
# starting to crawl main url:  https://www.bamboocp.com
# main_url:  https://www.bamboocp.com  is not valid
# starting to crawl main url:  https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf
#
#
# these are the children links we crawled
# ['/en/about-us/organisational-structure/ethics-office/', '/en/documents/project-related-procurement/standard-bidding-documents/', '/en/topics-and-sectors/initiatives-partnerships/africa-climate-change-fund/', '/en/documents/evaluation-reports/evaluation-working-paper/', '/en/documents/financial-information/financial-statements-and-data/', '/en/countries/north-africa/morocco/', '/en/projects-and-operations/project-cycle/implementation/', '/en/projects-and-operations/financial-management/financial-management-policies-procedures/', '/en/documents/evaluation-reports/evaluation-work-programme/', '/en/projects-and-operations/project-cycle/loan-effectiveness/', '/en/topics-and-sectors/initiatives-partnerships/zimbabwe-multi-donor-trust-fund/', '/en/about-us/corporate-procurement/vendor-kiosk/', '/en/documents/budget-documents/', '/en/countries/north-africa/mauritania/', '/en/topics-and-sectors/sectors/environment/', '/en/topics-and-sectors/initiatives-partnerships/afdb-oecd-joint-initiative/', '/en/countries/east-africa/south-sudan/', '/en/news-and-events/multimedia/', 'https://vimeo.com/296381533', '/en/about-us/corporate-information/african-development-fund-adf/adf-recipient-countries/', '/en/knowledge/african-development-institute/strategic-cooperation/', '/en/about-us/careers/current-vacancies/', '/en/about-us/corporate-information/history/', '/en/countries/east-africa/', '/en/countries/west-africa/burkina-faso/', '/en/topics-and-sectors/sectors/education/', '/en/topics-and-sectors/initiatives-partnerships/africa-trade-fund/', '/en/news-and-events/african-development-bank-investments-transform-madagascars-key-rice-regions-18534/', '/en/documents/financial-information/risk-management/', '/en/documents/publications/afdb-in-10/', '/en/documents/project-operations/country-portfolio-performance-review/', '/en/news-and-events/kenya-goes-all-out-for-renewable-energy-18559/', '/en/documents/publications/country-brochure/', '/en/projects-and-operations/financial-management/', '/en/knowledge/publications/capacity-focus/', '/en/projects-and-operations/procurement/projects-procurements-services-contacts/', '/en/countries/central-africa/madagascar/', '/en/countries/east-africa/uganda/', '/en/documents/knowledge/african-economic-conference/', '/en/topics-and-sectors/initiatives-partnerships/middle-income-countries/', 'https://vimeo.com/296381716', '/en/projects-and-operations/procurement/', '/en/topics-and-sectors/sectors/agriculture-agro-industries/', '/en/documents/project-related-procurement/procurement-notices/', '/en/about-us/careers/current-vacancies/consultants/junior-consultants/', '/en/topics-and-sectors/initiatives-partnerships/african-natural-resources-centre/', '/en/topics-and-sectors/initiatives-partnerships/trade-finance-program/', '/en/documents/compliance-reviews/irm-annual-report/', '/en/projects-and-operations/project-cycle/loan-signing/', '/en/countries/west-africa/nigeria/', '/en/topics-and-sectors/initiatives-partnerships/sustainable-energy-fund-for-africa/', '/en/topics-and-sectors/initiatives-partnerships/deauville-partnership/', '/en/countries/east-africa/djibouti/', '/en/countries/west-africa/cote-d%e2%80%99ivoire/', '/en/documents/publications/', '/en/topics-and-sectors/initiatives-partnerships/africa-ndc-hub/', '/en/about-us/organisational-structure/independent-review-mechanism-irm/', 'https://www.flickr.com/photos/afdbgroup/', '/en/knowledge/african-development-institute/', '/en/projects-and-operations/project-cycle/project-appraisal/', '/en/knowledge/publications/country-assessment-of-agricultural-statistical-systems-in-africa/', '/en/knowledge/publications/millennium-development-goals-mdgs-report/', '/en/documents/legal-documents/loan-and-grant-conditions/', '/en/topics-and-sectors/initiatives-partnerships/multi-partner-somalia-infrastructure-fund-sif/', 'https://esa.afdb.org/page/documents', 'http://idev.afdb.org/', '/en/documents/evaluation-reports/project-evaluations/', 'https://vimeo.com/296380714', '/en/conta ...
# www.afdb.org  and  vimeo.com  may not be relevent
# These are texts under http://idev.afdb.org/
# number of items grabed are 15
# number of items after filtering 5
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/countries/north-africa/morocco/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/about-us/organisational-structure/ethics-office/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/projects-and-operations/procurement/projects-procurements-services-contacts/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/topics-and-sectors/initiatives-partnerships/afdb-oecd-joint-initiative/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/topics-and-sectors/sectors/human-capital-development/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/documents/project-operations/country-portfolio-performance-review/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/knowledge/african-development-institute/strategic-cooperation/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/topics-and-sectors/initiatives-partnerships/sustainable-energy-fund-for-africa/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/topics-and-sectors/initiatives-partnerships/zimbabwe-multi-donor-trust-fund/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/topics-and-sectors/initiatives-partnerships/african-natural-resources-centre/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/countries/southern-africa/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/topics-and-sectors/sectors/education/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/knowledge/publications/tracking-africa%e2%80%99s-progress-in-figures/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/projects-and-operations/financial-products/african-development-bank/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/projects-and-operations/procurement/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/documents/evaluation-reports/project-evaluations/ invalid
# www.afdb.org  and  vimeo.com  may not be relevent
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/topics-and-sectors/initiatives-partnerships/migration-and-development-initiative/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/documents/evaluation-reports/country-assistance-evaluations/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/countries/north-africa/egypt/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/knowledge/publications/country-assessment-of-agricultural-statistical-systems-in-africa/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/about-us/corporate-information/african-development-fund-adf/adf-financed-projects/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/topics-and-sectors/initiatives-partnerships/africa-ndc-hub/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/projects-and-operations/project-cycle/implementation/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/documents/project-related-procurement/standard-bidding-documents/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/countries/central-africa/madagascar/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/about-us/careers/current-vacancies/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/topics-and-sectors/initiatives-partnerships/africa-trade-fund/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/topics-and-sectors/topics/environmental-social-and-governance-esg/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/countries/west-africa/benin/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/countries/east-africa/south-sudan/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/topics-and-sectors/initiatives-partnerships/deauville-partnership/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/documents/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/news-and-events/kenya-goes-all-out-for-renewable-energy-18559/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/documents/administrative-tribunal/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/projects-and-operations/project-cycle/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/topics-and-sectors/sectors/agriculture-agro-industries/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/about-us/corporate-procurement/vendor-kiosk/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/contact-us/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/topics-and-sectors/initiatives-partnerships/access-to-finance-for-smes-through-fis/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/countries/central-africa/gabon/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/topics-and-sectors/initiatives-partnerships/trade-finance-program/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/countries/west-africa/mali/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/knowledge/publications/millennium-development-goals-mdgs-report/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/topics-and-sectors/topics/quality-assurance-results/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/topics-and-sectors/topics/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/countries/east-africa/uganda/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/topics-and-sectors/initiatives-partnerships/africa-climate-change-fund/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/about-us/organisational-structure/independent-review-mechanism-irm/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/documents/compliance-reviews/irm-annual-report/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/projects-and-operations/financial-management/financial-management-policies-procedures/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/about-us/mission-strategy/objectives/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/documents/budget-documents/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/topics-and-sectors/initiatives-partnerships/african-guarantee-fund-for-small-and-medium-sized-enterprises/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/documents/environmental-social-assessments/environmental-and-social-management-plans-esmp/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/documents/policy-documents/policies-on-cross-cutting-issues/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/countries/west-africa/guinea/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/rss-feeds/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/about-us/corporate-information/history/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/documents/publications/country-brochure/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/documents/project-related-procurement/procurement-notices/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/news-and-events/multimedia/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/news-and-events/african-development-bank-investments-transform-madagascars-key-rice-regions-18534/ invalid
# www.afdb.org  and  vimeo.com  may not be relevent
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/topics-and-sectors/initiatives-partnerships/multi-donor-governance-trust-fund/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/documents/legal-documents/loan-and-grant-conditions/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/topics-and-sectors/initiatives-partnerships/climate-investment-funds-cif/ invalid
# www.afdb.org  and  www.flickr.com  may not be relevent
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/documents/knowledge/african-economic-conference/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/documents/evaluation-reports/evaluation-working-paper/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/countries/west-africa/ghana/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/about-us/organisational-structure/board-of-directors/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/projects-and-operations/project-cycle/loan-signing/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/documents/environmental-social-assessments/executive-summary-of-environmental-and-social-impact-assessments/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/documents/evaluation-reports/evaluation-work-programme/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/countries/central-africa/chad/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/countries/east-africa/djibouti/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/topics-and-sectors/initiatives-partnerships/multi-partner-somalia-infrastructure-fund-sif/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/countries/north-africa/mauritania/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/countries/east-africa/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/documents/project-related-procurement/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/about-us/careers/current-vacancies/consultants/junior-consultants/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/projects-and-operations/financial-management/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/countries/east-africa/sudan/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/news-and-events/the-2018-mid-term-review-of-the-african-development-fund-kigali-rwanda-18598/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/documents/financial-information/risk-management/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/documents/compliance-reviews/requests-register/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/documents/departmental-annual-reports/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/cookies-privacy-policy/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/about-us/corporate-information/african-development-fund-adf/adf-recipient-countries/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/knowledge/african-development-institute/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/documents/financial-information/financial-statements-and-data/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/topics-and-sectors/initiatives-partnerships/middle-income-countries/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/news-and-events/loans-grants/approvals/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/countries/west-africa/nigeria/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/knowledge/statistics/statistical-capacity-building/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/countries/central-africa/democratic-republic-of-congo/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/countries/west-africa/cote-d%e2%80%99ivoire/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/documents/project-related-procurement/procurement-statistics/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/topics-and-sectors/topics/structural-transformation/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/about-us/careers/employment-of-short-term-staff/ invalid
# These are texts under https://esa.afdb.org/page/documents
# number of items grabed are 0
# number of items after filtering 0
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/projects-and-operations/project-cycle/loan-effectiveness/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/topics-and-sectors/initiatives-partnerships/africa-energy-market-place/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/knowledge/publications/national-strategy-for-the-development-of-statistics-nsds/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/about-us/mission-strategy/operational-priorities/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/documents/corporate-procurement/invitation-for-bids-ifb/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/knowledge/publications/capacity-focus/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/documents/publications/afdb-in-10/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/topics-and-sectors/sectors/environment/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/topics-and-sectors/initiatives-partnerships/multidonor-water-partnership-program/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/projects-and-operations/project-cycle/project-appraisal/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/countries/west-africa/burkina-faso/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/documents/publications/working-paper-series/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/projects-and-operations/project-cycle/post-evaluation/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/topics-and-sectors/sectors/health/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/knowledge/publications/compendium-of-statistics-on-bank-group-operations/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/topics-and-sectors/initiatives-partnerships/strategic-partnership-with-africa/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/topics-and-sectors/sectors/information-communication-technology/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/countries/southern-africa/zambia/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/countries/central-africa/congo/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/documents/publications/afdb-statistics-pocket-book/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/documents/publications/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/topics-and-sectors/initiatives-partnerships/global-environment-facility-gef/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/topics-and-sectors/initiatives-partnerships/african-financial-markets-initiative-afmi/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/topics-and-sectors/topics/industrialization/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/topics-and-sectors/initiatives-partnerships/enhanced-private-sector-assistance-for-africa-epsa-initiative/ invalid
# url: https://www.afdb.org/en/about-us/corporate-information/african-development-fund-adf/en/topics-and-sectors/initiatives-partnerships/seed-capital-assistance-facility-scaf/ invalid
# ...
# number of items grabed are 0
# number of items after filtering 0
# These are texts under https://www.dwmarkets.com/news-publications/
# number of items grabed are 37
# number of items after filtering 5
# These are texts under https://www.dwmarkets.com/contact/
# number of items grabed are 0
# number of items after filtering 0
# These are texts under https://www.dwmarkets.com/careers/
# number of items grabed are 5
# number of items after filtering 5
# These are texts under https://www.dwmarkets.com/our-financing-at-work/
# number of items grabed are 5
# number of items after filtering 4
# These are texts under https://www.dwmarkets.com/careers/
# number of items grabed are 5
# number of items after filtering 5
# These are texts under https://www.dwmarkets.com/partnerships/
# number of items grabed are 1
# number of items after filtering 0
# These are texts under https://www.dwmarkets.com/our-history/
# number of items grabed are 47
# number of items after filtering 18
# These are texts under https://www.dwmarkets.com/who-we-are/
# number of items grabed are 0
# number of items after filtering 0
# starting to crawl main url:  https://www.dobequity.nl
# main_url:  https://www.dobequity.nl  is not valid
# starting to crawl main url:  https://www.gawacapital.com
# main_url:  https://www.gawacapital.com  is not valid
# starting to crawl main url:  https://www.goodcap.org
# main_url:  https://www.goodcap.org  is not valid
# starting to crawl main url:  https://www.gbfund.org
# main_url:  https://www.gbfund.org  is not valid
# starting to crawl main url:  https://www.grayghostventures.com
# main_url:  https://www.grayghostventures.com  is not valid
# starting to crawl main url:  https://www.grofin.com
#
#
# these are the children links we crawled
# ['http://www.grofinblog.com/', 'https://www.grofin.com/language/en/about_grofin/', 'http://www.grofin.com/language/en/business_support/#section1_supportbeyondfinance', 'http://www.grofin.com/language/en/legal-notices/', 'https://www.grofin.com/language/en/partners/', 'https://www.grofin.com', 'http://www.grofin.com/language/en/entrepreneurs/#section5_howwefinance', 'http://www.grofin.com/language/en/business_support/#section2_howweworkwithsmes', 'http://www.grofin.com/language/en/investors/#section4_investorsandfunders', 'http://www.nomou-mena.com', 'http://www.grofin.com/language/en/about_grofin/#section7_ourinvestorsandfunders', 'http://www.grofin.com/language/en/about_grofin/#section3_whereweoperate', 'http://www.grofin.com/language/en/entrepreneurs/#section8_stillhavequestions', 'http://www.grofin.com/language/en/entrepreneurs/#section2_whychoosegrofin', 'http://www.grofin.com/language/en/about_grofin/#section6_sectorsoffocus', 'http://www.grofin.com/language/en/about_grofin/#section8_ourpeople', 'http://www.grofin.com/language/en/investors/#section2_sectorsoffocus', 'http://www.grofin.com/language/en/about_grofin/#section5_thegrofinmodel', 'https://www.grofin.com/language/en/careers/', 'http://www.grofin.com/language/en/business_support/#section3_financeexpertisesuccess', 'http://www.grofin.com/language/en/entrepreneurs/#section7_grofinclientsuccess', 'https://www.grofin.com/language/en/customercharter/', 'http://www.grofin.com/language/en/entrepreneurs/#section1_grofinmorethanfinance', 'https://www.grofin.com/language/en/investors/', 'http://www.grofin.com/language/en/about_grofin/#section9_getintouch', 'https://www.instagram.com/grofingroup/', 'https://www.youtube.com/user/GroFinGroup', 'https://www.grofin.com/language/en/home/', 'https://www.grofin.com/language/en/business_support/', 'http://www.grofin.com/language/en/investors/#section6_speakinvestment', 'https://www.grofin.com/language/en/contact-us/', 'http://www.grofin.com/language/en/investors/#section5_grofinclientsuccess', 'http://www.grofin.com/language/en/business_support/#section4_businesssupportsuccess', 'https://www.grofin.com/language/en/resources/', 'http://www.grofin.com/language/en/about_grofin/#section4_ourobjective', 'https://twitter.com/GroFin', 'http://www.grofin.com/language/en/business_support/#businesssupportguides', 'http://www.grofin.com/language/en/business_support/#section5_speaktobusinesssupport', 'https://www.grofin.com/language/en/entrepreneurs/', 'http://www.grofin.com/language/en/contact-us/#section1_whistleblowing_hotline', 'https://www.grofin.com/language/en/home', 'http://www.grofin.com/language/en/about_grofin/#section1_whoweare', 'http://www.grofin.com/language/en/about_grofin/#section2_whyweexist', 'http://www.grofin.com/language/en/entrepreneurs/#section6_whereweoperate', 'https://www.facebook.com/GroFinGroup', 'http://www.grofin.com/language/en/entrepreneurs/#section3_whowefinance', 'http://www.grofin.com/language/en/investors/#section_sdgs', 'http://www.grofin.com/language/en/investors/#section3_esgmgmt', 'https://www.grofin.com/language/en/apply/', 'https://www.linkedin.com/company/grofin', 'http://www.grofin.com/language/en/investors/#section1_investinsme', 'https://www.grofin.com/language/fr/accueil/']
# These are texts under http://www.grofin.com/language/en/legal-notices/
# number of items grabed are 6
# number of items after filtering 2
# These are texts under http://www.grofin.com/language/en/business_support/#section2_howweworkwithsmes
# number of items grabed are 26
# number of items after filtering 16
# These are texts under http://www.grofin.com/language/en/business_support/#section1_supportbeyondfinance
# number of items grabed are 26
# number of items after filtering 16
# These are texts under http://www.grofin.com/language/en/business_support/#section3_financeexpertisesuccess
# number of items grabed are 26
# number of items after filtering 16
# These are texts under http://www.grofin.com/language/en/entrepreneurs/#section5_howwefinance
# These are texts under http://www.grofin.com/language/en/about_grofin/#section7_ourinvestorsandfunders
# number of items grabed are 32
# number of items grabed are 40
# number of items after filtering 16
# These are texts under http://www.grofin.com/language/en/entrepreneurs/#section2_whychoosegrofin
# These are texts under http://www.grofin.com/language/en/entrepreneurs/#section7_grofinclientsuccess
# number of items after filtering 23
# These are texts under http://www.grofin.com/language/en/entrepreneurs/#section8_stillhavequestions
# These are texts under http://www.grofin.com/language/en/entrepreneurs/#section1_grofinmorethanfinance
# number of items grabed are 32
# These are texts under http://www.grofin.com/language/en/about_grofin/#section6_sectorsoffocus
# These are texts under http://www.grofin.com/language/en/about_grofin/#section5_thegrofinmodel
# These are texts under http://www.grofin.com/language/en/about_grofin/#section8_ourpeople
# number of items after filtering 16
# These are texts under http://www.grofin.com/language/en/about_grofin/#section3_whereweoperate
# number of items grabed are 32
# number of items grabed are 32
# number of items grabed are 32
# number of items grabed are 40
# number of items grabed are 40
# number of items grabed are 40
# number of items after filtering 16
# number of items after filtering 16
# number of items after filtering 16
# number of items after filtering 23
# number of items after filtering 23
# number of items after filtering 23
# number of items grabed are 40
# number of items after filtering 23
# These are texts under https://www.grofin.com/language/en/customercharter/
# number of items grabed are 22
# number of items after filtering 11
# These are texts under http://www.grofin.com/language/en/investors/#section4_investorsandfunders
# These are texts under http://www.grofin.com/language/en/investors/#section2_sectorsoffocus
# These are texts under https://www.grofin.com/language/en/partners/
# number of items grabed are 63
# number of items grabed are 63
# number of items grabed are 30
# number of items after filtering 41
# number of items after filtering 41
# These are texts under https://www.grofin.com/language/en/careers/
# number of items after filtering 19
# number of items grabed are 24
# number of items after filtering 13
# These are texts under https://www.grofin.com/language/en/about_grofin/
# number of items grabed are 40
# number of items after filtering 23
# These are texts under http://www.grofin.com/language/en/about_grofin/#section9_getintouch
# number of items grabed are 40
# number of items after filtering 23
# These are texts under https://www.grofin.com/language/en/investors/
# number of items grabed are 63
# number of items after filtering 41
# These are texts under http://www.grofin.com/language/en/business_support/#section4_businesssupportsuccess
# number of items grabed are 26
# number of items after filtering 16
# These are texts under http://www.grofin.com/language/en/business_support/#section5_speaktobusinesssupport
# number of items grabed are 26
# number of items after filtering 16
# These are texts under http://www.grofin.com/language/en/business_support/#businesssupportguides
# number of items grabed are 26
# number of items after filtering 16
# These are texts under http://www.grofin.com/language/en/about_grofin/#section4_ourobjective
# number of items grabed are 40
# number of items after filtering 23
# These are texts under https://www.grofin.com/language/en/home/
# number of items grabed are 1
# number of items after filtering 0
# These are texts under http://www.grofin.com/language/en/about_grofin/#section1_whoweare
# These are texts under http://www.grofin.com/language/en/about_grofin/#section2_whyweexist
# number of items grabed are 40
# number of items grabed are 40
# number of items after filtering 23
# number of items after filtering 23
# These are texts under http://www.grofin.com/language/en/investors/#section5_grofinclientsuccess
# These are texts under https://www.grofin.com/language/en/business_support/
# number of items grabed are 63
# These are texts under https://www.grofin.com/language/en/resources/
# number of items grabed are 26
# number of items after filtering 41
# number of items after filtering 16
# number of items grabed are 29
# These are texts under http://www.grofin.com/language/en/investors/#section6_speakinvestment
# number of items after filtering 3
# These are texts under http://www.grofin.com/language/en/entrepreneurs/#section6_whereweoperate
# number of items grabed are 63
# number of items after filtering 41
# number of items grabed are 32
# number of items after filtering 16
# These are texts under https://www.grofin.com/language/en/entrepreneurs/
# These are texts under http://www.grofin.com/language/en/entrepreneurs/#section3_whowefinance
# number of items grabed are 32
# number of items grabed are 32
# number of items after filtering 16
# number of items after filtering 16
# url: https://www.linkedin.com/company/grofin invalid
# These are texts under http://www.grofin.com/language/en/investors/#section_sdgs
# number of items grabed are 63
# number of items after filtering 41
# These are texts under https://www.grofin.com/language/fr/accueil/
# These are texts under https://www.grofin.com/language/en/apply/
# number of items grabed are 1
# number of items grabed are 29
# number of items after filtering 0
# number of items after filtering 18
# These are texts under http://www.grofin.com/language/en/investors/#section3_esgmgmt
# number of items grabed are 63
# number of items after filtering 41
# These are texts under http://www.grofin.com/language/en/investors/#section1_investinsme
# number of items grabed are 63
# number of items after filtering 41
# www.grofin.com  and  www.instagram.com  may not be relevent
# www.grofin.com  and  twitter.com  may not be relevent
# www.grofin.com  and  www.youtube.com  may not be relevent
# These are texts under http://www.grofinblog.com/
# number of items grabed are 20
# number of items after filtering 20
# These are texts under http://www.grofin.com/language/en/contact-us/#section1_whistleblowing_hotline
# number of items grabed are 81
# number of items after filtering 5
# These are texts under https://www.grofin.com/language/en/contact-us/
# number of items grabed are 81
# number of items after filtering 5
# www.grofin.com  and  www.facebook.com  may not be relevent
# starting to crawl main url:  https://www.heartcapital.co.za
#
#
# these are the children links we crawled
# ['https://www.facebook.com/heartcapital', 'https://www.heartcapital.co.za/our-story', 'https://www.youtube.com/user/HeartCapitalZA?feature=watch', 'https://www.heartcapital.co.za', 'https://www.heartcapital.co.za/legacy-gallery', 'https://www.heartcapital.co.za/contact-us', 'http://www.linkedin.com/company/heart-capital', 'http://instagram.com/heartcapitalza', 'https://www.heartcapital.co.za/get-involved', '//www.wix.com/lpviral/enviral?utm_campaign=vir_wixad_live&adsVersion=white&orig_msid=de6feef5-b73c-41d9-9143-32d4e98abba2', 'https://twitter.com/heartcapitalZA']
#
# url: http://www.linkedin.com/company/heart-capital invalid
# www.heartcapital.co.za  and  twitter.com  may not be relevent
# url: https://www.heartcapital.co.za//www.wix.com/lpviral/enviral?utm_campaign=vir_wixad_live&adsVersion=white&orig_msid=de6feef5-b73c-41d9-9143-32d4e98abba2 invalid
# www.heartcapital.co.za  and  www.youtube.com  may not be relevent
# These are texts under https://www.heartcapital.co.za/contact-us
# number of items grabed are 27
# number of items after filtering 1
# www.heartcapital.co.za  and  www.instagram.com  may not be relevent
# These are texts under https://www.heartcapital.co.za/our-story
# number of items grabed are 53
# number of items after filtering 15
# These are texts under https://www.heartcapital.co.za/get-involved
# number of items grabed are 41
# number of items after filtering 7
# www.heartcapital.co.za  and  www.facebook.com  may not be relevent
# These are texts under https://www.heartcapital.co.za/legacy-gallery
# number of items grabed are 163
# number of items after filtering 74
# starting to crawl main url:  https://www.ignite-fund.org
# main_url:  https://www.ignite-fund.org  is not valid
# starting to crawl main url:  https://www.iachl.com
#
#
# these are the children links we crawled
# ['parent.php?root=portfolio&link=overview', 'http://www.agra-alliance.org', 'parent.php?root=join&link=experts', 'parent.php?root=approach&link=strategy', 'parent.php?root=portfolio&link=profiles', 'language.php?lang=fr', 'parent.php?root=about&link=overview', 'http://www.tagedstudio.com', 'parent.php?root=join&link=investors', 'parent.php?root=approach&link=criteria', 'parent.php?root=portfolio&link=impact', 'parent.php?root=approach&link=faqs', 'parent.php?root=about&link=directors', 'https://www.iachl.com', 'http://www.fmo.nl', 'parent.php?root=careers/', 'http://www.cdcgroup.com', 'parent.php?root=clients/', 'parent.php?root=about&link=partners', 'parent.php?root=resources&link=news', 'parent.php?root=about&link=team', 'parent.php?root=apps/', 'parent.php?root=contact']
#
# url: https://www.iachl.comparent.php?root=portfolio&link=profiles invalid
# url: https://www.iachl.comparent.php?root=join&link=experts invalid
# url: https://www.iachl.comparent.php?root=portfolio&link=overview invalid
# url: https://www.iachl.comparent.php?root=approach&link=strategy invalid
# url: https://www.iachl.comparent.php?root=contact invalid
# url: https://www.iachl.comparent.php?root=join&link=investors invalid
# url: https://www.iachl.comparent.php?root=approach&link=faqs invalid
# url: https://www.iachl.comparent.php?root=approach&link=criteria invalid
# url: https://www.iachl.comparent.php?root=about&link=team invalid
# url: https://www.iachl.comparent.php?root=clients/ invalid
# url: https://www.iachl.comparent.php?root=resources&link=news invalid
# url: https://www.iachl.comparent.php?root=about&link=directors invalid
# url: https://www.iachl.comparent.php?root=about&link=partners invalid
# url: https://www.iachl.comparent.php?root=portfolio&link=impact invalid
# url: https://www.iachl.comparent.php?root=about&link=overview invalid
# url: https://www.iachl.comparent.php?root=apps/ invalid
# url: https://www.iachl.comparent.php?root=careers/ invalid
# url: https://www.iachl.comlanguage.php?lang=fr invalid
# url: http://www.agra-alliance.org invalid
# www.iachl.com  and  www.cdcgroup.com  may not be relevent
# www.iachl.com  and  www.fmo.nl  may not be relevent
# starting to crawl main url:  https://www.ihsinvestments.co.za

# %%
database.to_csv("crawled_database.csv")
# Out:
# array(['Agriculture and agribusiness accounts for 32 percent of GDP in Sub-Saharan Africa and employs 65 percent of the work force. It is likely to have a bigger impact on poverty reduction than in other sectors as it offers the most direct route of raising returns to poor people’s main assets, i.e. land and labour. The AECF’s work in the agriculture sector is the oldest and largest of its investments with a total of US$ 183 million committed across Africa. The Fund supports businesses to establish a new activity or expand existing businesses across the value chain, as long as the primary beneficiaries of the businesses are rural households living on less than US$ 2 per day.\xa0',
#        'Accessible Innovations for Smallholders:\xa0The Fund invests in businesses that have the potential to reach smallholder farmers to improve agricultural productivity and increase household income and food security. We work in a wide range of value chains and production systems to increase access to better quality agricultural inputs, improved seeds varieties and livestock vaccines, introduce new farming systems and agribusiness models.\xa0',
#        'Scaling Up Innovative Businesses:\xa0The Fund acts as the missing link between agricultural research and smallholder farmers by financing the commercialization of new technologies where others will not. Key investment areas include new fertilizers, vaccines, integrated pest management, disease resistant crops and soil testing.',
#        'Post Conflict and Fragile States:\xa0Post conflict and fragile states face particular challenges but the private sector is a key player in supporting the reconstruction of agribusinesses in these countries. With other sources of capital largely absent, the AECF provides critical funding which has been a key driver in the re-establishment of agricultural value chains in Zimbabwe, Mozambique, South Sudan, Somalia, Sierra Leone, Liberia and Democratic Republic of Congo (DRC).\xa0',
#        'Open data and media to increase productivity:\xa0The Fund supports low cost communication technologies and business models for information and data sharing that can reach a large audience and provide information to smallholder farmers enabling them to improve agricultural productivity and incomes.',
#        'Promoting Financial Inclusion and Mobile Finance:\xa0Improving access to finance is a priority for AECF. The Fund supports projects that use mobile money systems, create local financing mechanisms, introduce weather based insurance and establish credit systems. This improves agricultural productivity and household incomes. It also establishes non-collateral credit scoring for smallholders that enable them to access formal financial systems in the future.',
#        'The AECF runs competitions\xa0targeting specific economic sectors in agribusiness, renewable energy, resilience\xa0and rural financial services in specific countries in Africa, or development corridors involving several countries.\xa0Each competition typically can have more than one\xa0Funding Round for additional applications depending on funding partner support. The amount of funding that the AECF can award to a single business is\xa0between US $100,000 and US$ 1.5 million, although this amount may vary depending on the competition. Every business entering the competitions must meet specific eligibility criteria.',
#        'REACT SSA seeks to catalyze the private sector to increase supply of cleaner fuels, raise awareness of the dangers from indoor air pollution, demonstrate how new knowledge in renewable energy technologies can be put into practice in ways that benefit the poor especially women, provide evidence on challenges in policy formulation and implementation.',
#        'Target Countries: Burkina Faso, Ethiopia, Kenya, Liberia, Mali, Mozambique, Zimbabwe, Sudan and Somalia',
#        'Eligibility: the Private sector with relevant renewable energy businesses in one or more of the seven participating countries',
#        'The Investing in Women (IIW) window is an initiative working to create a more gender inclusive agricultural value chain in order to address rural poverty, food insecurity and gender equality by increasing the proportion of women generating income from agribusiness as well as the number and quality of jobs for women working in agricultural value chains.',
#        'IIW will be piloted in Ethiopia, Sierra Leone, Cote d’Ivoire & Burkina Faso with an initial budget of USD5.9 million expected to fund 10-30 businesses in specific agriculture value chains. AECF plans to increase the fund size to USD 50 million to cover the rest of sub-Saharan African countries as funding becomes available. The approach is based on the AECF challenge fund model, with modifications to address structural barriers that limit women’s access to finance.',
#        'The first stage is submission of an initial application form where the applicants write about their business ideas, and about their company(s) on a template provided.',
#        'If short-listed after the initial assessment, the applicant will be asked to submit a more comprehensive Business Plan for assessment.',
#        'During this stage, the AECF engages with and visits the shortlisted applicants preparing Business Plans to understand their model and innovations better.',
#        'Final Business Plans are presented to an independent Investment Committee who meet and decide which company projects to fund.',
#        'Successful businesses are invited for an Induction Workshop where post-award processes such as progress reporting are made clear to the company prior to contracting.',
#        'The contracting phase is rigorous and formalizes obligations and deliverables committed to by the grantee so as to meet all contracting terms and inform disbursement of funds.',
#        'Disbursements are actualized by AGRA following disbursement schedules agreed to at the time of contracting, and are dependent on key deliverables being met at each stage of the project.',
#        'Grantees must self-report semi-annually. They can however chose to report quarterly if they need funds disbursed.',
#        'An AECF Project Manager leads monitoring and evaluation visits to the projects semi-annually or quarterly, to assess technical and financial progress.',
#        'The window\xa0will support innovative and transformational business models that help people to access electricity through off-grid solar household systems and give commercially viable businesses the developmental support to create sustainable HS markets. It also aims to ensure access to electricity is affordable to the rural and peri-urban poor and to capture and disseminate ecosystem lessons on how solar household systems delivers positive social and economic impact for those same people. The countries targeted Malawi, Zambia, Zimbabwe and Sierra Leone. Keep checking for updates on the companies that have been awarded.',
#        'The AECF Agribusiness Africa Window (AAW) is one of the funding windows at the AECF that supports business ideas in the fields of agribusiness, financial services and value chains to be implemented in Africa.\xa0',
#        'The AECF Agribusiness Africa Window (AAW) funds\xa0private sector companies from anywhere in the world to grow or establish innovative agribusiness related projects in sub-Saharan Africa that benefit rural communities. To date, the AECF has conducted 2 rounds, with a total of 41 projects approved for\xa0funding.',
#        'The\xa0AECF General Window\xa0(GW)\xa0is a funding window\xa0of the AECF that supports business ideas in the fields of agribusiness, financial services and value chains. GW was the first AECF competition opened in 2008.',
#        'The AECF General Window (GW) funds\xa0private sector companies from anywhere in the world to grow or establish innovative agribusiness related projects in sub-Saharan Africa that benefit rural communities. To date, the AECF has conducted 3 rounds, with a total of 17 projects approved for funding.',
#        'The AECF Post Conflict Window (PCW) was created to provide special opportunities for applicants from post-conflict countries\xa0such as DRC, Liberia, Sierra Leone, Somalia and Somaliland.',
#        'The AECF Post Conflict Window (PCW) funds\xa0private sector companies from anywhere in the world to grow or establish innovative agribusiness related projects in Post Conflict States that benefit rural communities. To date, the AECF has conducted 1 round,\xa0with a total of 20 projects approved for funding.',
#        'The AECF Research Into Business Window (RIB)\xa0is a special window of the AECF that\xa0aims to\xa0stimulate\xa0the private sector to commercialize existing, accessible and near complete agricultural research and technology products for the benefit of rural communities. To date, the AECF has conducted 2 rounds, with a total of 17 projects approved for funding.',
#        'The AECF South Sudan Window (SSW) is a funding window of the AECF that supports business ideas in the fields of agribusiness, associated service sectors and value chains which extend from the Republic of South Sudan to local and international markets.',
#        'The AECF South Sudan Window (SSW) funds\xa0private sector companies from anywhere in the world to grow or establish innovative agribusiness related projects in South Sudan that benefit rural communities. To date, the AECF has conducted 1 round, with a total of 6 projects approved for funding.',
#        'AECF TZAW is\xa0 a special fund of the AECF open to agribusiness ideas for Tanzania only.The widest possible range of agribusiness related projects are eligible for support.',
#        'The AECF Tanzania Window (TZAW) funds\xa0private sector companies from anywhere in the world to grow or establish innovative agribusiness related projects in Tanzania that benefit rural communities. To date, the AECF has conducted 4 rounds, with a total of 55 projects approved for funding.',
#        'The AECF Zimbabwe Window (ZW) funds\xa0private sector companies from anywhere in the world to grow or establish innovative agribusiness related projects in Zimbabwe that benefit rural communities. To date, the AECF has conducted 3 rounds, with a total of 30 projects approved for funding.',
#        'Daniel is a seasoned development finance professional with more than 25 years-experience of\xa0global senior leadership in private sector enterprise development, partnership and resource mobilization, management consulting, manufacturing, logistics and oil & gas across\xa0Africa. He also has significant prior operations experience at the African Development Bank Group. Prior to AECF, Daniel was the CEO of an SME funding micro-finance entity focused on deepening financial inclusion. His diverse experience cuts across both the public and private sector, with strong interest in SME development. He has lived in West, East, North and Southern Africa. He is a mechanical engineer and holds an M.B.A. in strategic management and an MSc in finance.',
#        'Steve is an all-rounded finance professional with 18 years’ experience in Europe and Africa. Prior to joining AECF, Steve was a Senior Investment Director at AV-Ventures LLC, leading the set-up and investment activities of the agribusiness impact fund in Ghana.',
#        'Before coming back to Africa, Steve led various teams to execute on initiatives such as setting up and fundraising for a West Africa generalist fund; as senior risk manager focusing on equity fund risk and portfolio management at the European Investment Fund (€20bn AuM, part of EIB Group), as a financial and technology adviser to various West African financial institutions - including the African Development Bank - and as principal consultant in strategy, operations and technology for financial institutions in Europe with BearingPoint and Capco. His career started as a sales-trader and broker for Exane, followed by Viel-Tradition.',
#        'Steve is a constant learner, after completing an MSc. in International Management from Audencia Business School in France, he obtained an MSc in Finance from London Business School and an Executive Programme on Social Entrepreneurship from Stanford GSB. Stev has continued to develop his development finance, impact investing and managerial skills with professional trainings such CAIA (Alternative Investments), CIFE (Islamic Finance), Moody’s (Credit Risk), Toastmasters CC and CL. An Angel investor and coach to start-ups, Steve holds a number of board positions, including at Innohub, a start-up accelerator in Ghana',
#        'Pauline oversees efforts to establish, deepen and strengthen relationships with donors and partners to broaden AECF’s impact and reach.',
#        'She has a solid understanding of private sector and international development gained through over twenty years of experience.\xa0 She has worked with government, international and local development actors such as United Nations Industrial Development Organization (UNIDO), United Nations Development Program (UNDP) and has implemented programmes funded by the International Finance Corporation (IFC), the African Development Bank (AfDB) among others. While at UNIDO, Pauline received an Industrial Sustainability Award as the Manager of a Manufacturing Centre of Excellence. Prior to joining AECF, Pauline was Director, Business Development at African Management Services Company (AMSCO) where she managed the African Training and Management Services (ATMS) Foundation.',
#        'Pauline is a seasoned resource mobilizer, business development professional as well as a fund management and grants administration expert. She holds a Double MBA in Strategy and International Business from the University of Nairobi, Kenya. Pauline has attended a number of leadership training from various institutions including the Harvard and Stanford Business Schools.',
#        'Julie brings with her over 11 years’ experience in finance and accounting in private sector and NGO sector. \xa0',
#        'Prior to AECF, Julie was a manager at Deloitte where she managed and coordinated the Assurance and Advisory Department in auditing insurance companies and investment companies in the Cayman Islands. Part of her role was to lead a team of 20 auditors in providing auditing, accounting and related advisory services to public and private clients. She also has prior experience in working with NGOs in Kenya.\xa0',
#        'Julie is a Certified Public Accountant (CPA) registered in Kenya and also holds a Bachelor Degree in Business and Management (Banking and Finance) from Egerton University, Kenya.\xa0\n\xa0',
#        'Josephine, formerly Head of Legal Services at Spire Bank, is an advocate of the High court of Kenya, a Commissioner for Oaths, a Notary Public and a Certified Governance Auditor. She brings onboard business focused Legal and company secretarial professional experience of over 10-years and has a track record of hands on experience in legal practice and operations. Her specialization is in areas of Corporate governance, Legal Compliance and Administration, Leadership, Intellectual Property, Data Protection and Company Secretarial Services. She holds a Bachelor of Law Degree from Pune University, India and a Diploma in Law from the Kenya School of Law. She is a member of the Law Society of Kenya, East Africa Law Society as well as the Institute of Certified Public Secretaries of Kenya.\xa0',
#        'AGRA is a dynamic, African-led partnership working across the continent to help millions of small-scale farmers and their families lift themselves out of poverty and hunger. Through its programmes, AGRA develops practical solutions to significantly boost farm productivity and incomes whilst safeguarding the environment.',
#        'AGRA, with initial support from the Rockerfeller Foundation and the Bill & Melinda Gates Foundation, maintains offices in Nairobi, Kenya and Accra, Ghana.',
#        'Syngenta Foundation for Sustainable Agriculture (SFSA) is a Swiss-based non-profit organization, which focuses on creating value for resource-poor small farmers in developing countries through innovation in sustainable agriculture and the activation of value chains. SFSA’s Seeds2B program is aimed at improving choice of and access to quality seeds of improved varieties for the crops smallholder farmers need.',
#        'The Rt. Hon the Lord Boateng is a Barrister, former British MP, Cabinet Minister and British High Commissioner to South Africa. Brought up in Ghana, West Africa he is a frequent writer, broadcaster and lecturer on Africa. He founded his own market regulatory advisory company Akyem Law and Advisory, is on the Health Policy Advisory Board of Gilead Sciences and is an advisor to a number of other international companies.',
#        'As a member of the House of Lords, he sits on the Joint National Security Strategy Committee of the British Parliament and is Vice Chair of the All Party Parliamentary Group on Agriculture and Development. He is a Trustee of the Planet Earth Institute, Chairs Book Aid International, the English Speaking Union and the International Council of the Duke of Edinburgh’s Award.',
#        'A Methodist Lay Preacher, married to\xa0 Lady Janet Boateng, a Social Policy Analyst and Company Director. They have five children and six grandchildren.',
#        'Until July 2015, Mr. Prosper was Vice President for Global Services at the International Finance Corporation (IFC), the private sector arm of the World Bank Group. In that capacity, he co-led IFC’s global investment operations (totaling around US $20 billion a year), and advisory services covering all IFC investment and advisory activities worldwide, encompassing over 2,400 staff. He also supervised a portfolio of more than US $70 billion. One of his focus area included IFC’s activities in fragile and conflict-affected situations (FCS), a key priority for the WBG.\xa0',
#        'Mr. Prosper was earlier, Vice President for Sub-Saharan Africa, Latin America and the Caribbean (CAFLAC) where he led IFC’s investments and advisory services—delivering an investment program of about US $10 billion in fiscal year 2014 alone, and managing a portfolio of over US $20 billion. Under his leadership, CAFLAC generated over US $670 million in cash income in FY14 and was the largest and most profitable Operational Vice-presidency.',
#        "A Haitian national, Mr. Prosper became Vice President in February 2013. Prior to this, he was IFC Director for Latin America and the Caribbean responsible for all of IFC's activities in the region for one year. During Mr. Prosper’s tenure as a Director, IFC experienced its highest level of business ever in LAC, reaching US $6.5 billion that year. \xa0LAC also contributed to 40% of IFC’s profit, being the most profitable region of the institution. From July 2008 to August 2012, Mr. Prosper was the Director for Eastern and Southern Africa and a co-director of the Africa department. During Mr. Prosper’s tenure with the Africa department, IFC’s investments grew from US $140 million in fiscal year 2003 to US $4 billion in fiscal year 2012.",
#        'Mr. Prosper joined IFC in 2000 as a Chief Investment Officer for Financial Markets covering West and Central Africa and a year later became Manager, Financial Markets for Sub-Saharan Africa, relocating to Johannesburg in 2003. Shortly thereafter, he relocated to Nairobi as Manager for East Africa.\xa0',
#        "Prior to joining the IFC, from 1990 to 2000, Mr. Prosper worked for the Inter-American Investment Corporation (IIC) – today known as IDB Invest), eventually holding responsibility for all operations in Mexico, the Andean countries, Central America, Belize, and Panama. Between 1986 and 1990, he worked at SOFIHDES, a private development finance company in Haiti, where he eventually became Managing Director. During this period, Mr. Prosper was also a professor of mathematics, statistics, and managerial and corporate finance at the State University of Haiti. In the early 1980's, Mr. Prosper worked as Advisor to the Minister of State of Haiti on Financial, Economic, and Industrial Affairs. He was in charge of all negotiations with multilateral organizations, including the International Monetary Fund, the World Bank, and the Inter-American Development Bank.\nMr. Prosper is the recipient of the two most prestigious awards of the World Bank Group, the Diversity and Inclusion Leadership Award in 2010 and the Good Manager Award in 2011.\xa0",
#        'An expert in Fragile and Conflict Affected Situations, Mr. Prosper holds an M.B.A. He is also a civil engineer with a degree in Mathematics.',
#        'Mr. Prosper is fluent in Haitian Creole, French, English, Spanish, Portuguese and is proficient in Kiswahili.\n\xa0',
#        'Anne-Marie\xa0has 25 years’ experience in African financial and private sector development, with Development Finance Institutions, Consulting/Advisory Firms and Private Equity Funds, managing investment and development finance projects in 32 African Anglo, Franco and Luso-phone countries. She has worked during the course of her career for the World Bank, DFID and other DFIs. She joined, Alitheia Identify Managers as a Principal Partner and Co-Founder,\xa0 to raise a US $100 million Pan-African private equity fund, anchored by the African Development Bank, for growth SMEs focusing on women led business. In recent years she managed a US $42 million Pan African private equity fund for micro-finance, AfriCap Micro-finance Investment Company, and is now concluding the last exits, and she is currently the CEO of the Financial Sector Deepening-Mozambique (FSDMoç) fund, financed by the UK Government’s Department for International Development (DFID).',
#        'As a leader in enterprise finance, she currently sits on the Advisory Boards of Making Finance Work for Africa and Women’s World Banking, and the Board of Untu Micro-finance Bank, Zimbabwe. She is founding member of a Pan African network of Women in Finance, NFNV. Anne-Marie is a Zimbabwean, and holds a BSc Psychology, McGill University, Montreal and MA Economics, University of Toronto, Canada',
#        'Kola is the Managing Partner of Doreo Partners, an impact investing firm that leverages agriculture venture capital to drive youth employment, a critical need in Africa.',
#        'Kola brings significant leadership experience in venture capital, corporate finance, business development, marketing and operations, across four continents, North America, Europe, Asia and Africa with multiple global companies, including General Electric (GE), Abiomed and Notore.',
#        'In addition, Kola brings extensive public sector experience as the former Senior Advisor to the Nigerian Minister of Agriculture. Kola is globally recognized as a thought leader in African Agribusiness, with numerous speaking engagements at leading global conferences and is a regular Agribusiness contributor to CNBC. In recognition for his leadership in driving positive change on the African Continent he has received several global awards including the prestigious Eisenhower Fellowship, a leading leadership institute led by General Collin Powell.',
#        'Kola holds an MBA (Honors) from Harvard and Masters in Mechanical Engineering from Massachusetts Institute of Technology, MIT.',
#        'Duncan, a Kenyan national, is an accomplished senior executive who integrates strategy, organization, process, people, and technology to deliver business goals. A result-driven and forward-looking leader, Duncan is a visionary who has successfully developed and directed complex corporate change initiatives, enterprise growth initiatives, relationships, acquisitions, and risk management strategies.',
#        'He has a twenty-one year track record of consistent achievement in corporate finance, operations and general management with his most recent assignment being Regional Director/CEO – East Africa of a social venture fund and as Group Chief Finance Officer of a US$100M turnover private equity owned rail operator in Kenya and Uganda.',
#        'He has served on the boards of major organisations in East Africa and the UK, including: Rift Valley Railways Ltd, Scion Real, Philafe Engineering Ltd, Acacia Medical Centre Ltd, Botanical Extracts EPZ Ltd, Western Seed and Provident Capital Transfers Ltd (UK), First Access LLC, SolarNow LLC, Sanergy Ltd, TradeMark EA, Town and Country Housing Association (UK).',
#        'Prof. Poulter (British) is an elected Fellow of the United Kingdom Institute of Food Science and Technology and is a Visiting Professor and Senior Fellow at the Natural Resources Institute, University of Greenwich, where he was formerly the Director. Between 2014 and MAY 2017 he was Director of the AGRINATURA European Economic Interest Group – a pan European body representing European Universities and Research Institutes working in the field of tropical agricultural research, development and education.',
#        'Guy has an extensive track record of directing and leading multi-disciplinary agricultural research and development activities for the benefit of developing countries, development of strategies for multi donor collaboration towards attainment of development goals and has particular experience of the issues relating to the interaction of Members States and the European Commission in the field of international agricultural development under the umbrella of the European Union.',
#        'In the course of his duties, he has extensive international work and travel experience \xa0and has been at the fore front of advocacy for better policies for global food security and agricultural for development including hands on working experience in the European Commission in Europe Aid and DG Research and Innovation.',
#        'He is also a Special Adviser to the UK All Party Parliamentary Group for Food and Agriculture for Development.',
#        'Ms Dolika Banda is CEO of the African Risk Capacity Insurance Company Limited (ARC Ltd), Africa’s first catastrophe risk pool which provides parametric natural disaster insurance to African governments and is co-founded by UK DFID and German BMZ/KFW. She started the role in early September 2016.',
#        'A Zambian banking and finance expert, Ms Banda has more than 25 years of international banking and financial management experience with a focus on economic development in sub-Saharan Africa.',
#        'Most recently, Ms Banda was Regional Director for Africa at the UK’s Commonwealth Development Corporation (CDC) 2013 to 2015.\xa0Prior to that, Ms Banda worked at the World Bank Group’s International Finance Corporation for 16 years within its financial markets, credit, accounting and treasury departments. As Director of Financial Markets, she managed the IFC’s financial markets activities across sub-Saharan Africa, Latin America and the Caribbean.',
#        'Ms Banda has also held senior corporate and merchant banking positions at Barclays and Citibank in Zambia.\xa0She currently sits as a non-executive director on a number of boards including Ecobank Transnational Incorporated (“ETI”) and Harith-managed Pan Africa Infrastructure Development Facility (“PAIDF”).',
#        'The AECF was launched at the World Economic Forum Africa in 2007 and become operational in 2008\xa0to respond to the need for an Africa based fund that would support African business, particularly in the areas of finance and agriculture. It\xa0begun with a start-up capital from the United Kingdom and Dutch Governments, the Consultative Group to Assist the Poor (CGAP) and the International Fund for Agricultural Development (IFAD).',
#        'The AECF launched the first competition in 2008 and since then it has grown to be one of the largest challenge funds in Africa. Over the past 10 years, the AECF has conducted 27 competitions,\xa0received over 10,000 applications and\xa0approved funding to 266 business projects',
#        'The AECF REACT Household Solar competition will\xa0support innovative business models that improve access to electricity through off grid stand - alone household solar systems and deliver positive social and economic impacts in the four target countries.',
#        'AAW supports business ideas that will make a positive impact in the fields of agribusiness, financial services and value chains in Africa.',
#        'The AECF TZAW supports agribusinesses with good innovative ideas for implementation in Tanzania that will have a positive development impact.',
#        'The AECF REACT Window supports private sector investment and innovation in low cost, clean energy and climate change technologies.',
#        'The RIB Window aims to stimulate\xa0the private sector to commercialize existing, readily available and near complete agricultural research and technology products for the benefit of the rural poor in Africa.',
#        'The AECF General Window supports business ideas in the fields of agribusiness, financial services and value chains which extend across sub-Saharan Africa and international markets.',
#        'The AECF funding partners include the Governments of Australia, Canada, Denmark, the Netherlands, Sweden and the UK, as well as The Consultative Group to Assist the Poor (CGAP) and The International Fund for Agricultural Development (IFAD). Each funding partner has a focus area or geographical region that it wishes to impact upon, and the AECF provides the means to target those focus areas/regions, to award investees and monitor and evaluate their performance.',
#        'The Australian Government’s Department of Foreign Affairs and Trade (DFAT) has supported the AECF since 2009. They have supported the Zimbabwe and Research into Business windows.\xa0DFAT focuses on supporting sustainable economic growth through investments in good governance and capacity building in the agriculture, extractives and public policy sectors.',
#        'Since 2014, Global Affairs Canada has supported the AECF’s Africa Agribusiness window.\xa0Canada’s international assistance priorities include increasing food security, securing the future of children and youth, stimulating sustainable economic growth, advancing democracy, and promoting stability and security.',
#        'The Consultative Group to Assist the Poor (CGAP) is a global partnership of 34 leading organizations that seek to advance financial inclusion and is housed at the World Bank. CGAP develops innovative solutions through practical research and active engagement with financial service providers, policy makers, and funders to enable approaches at scale.\xa0CGAP were one of the founding members of the AECF and funded\xa0the General window.',
#        'The Danish International Development Agency (DANIDA) has supported the AECF since 2011 i.e.\xa0the REACT Kenya window.\xa0DANIDA are particularly interested in the support of adaptation to climate change businesses as well as the renewable energy sector.',
#        'The International Fund for Agricultural Development (IFAD), a specialized agency of the United Nations, was established as an international financial institution in 1977. IFAD is dedicated to eradicating rural poverty in developing countries.\xa0IFAD is one of the founding members of AECF and funded\xa0the General window.',
#        'SIDA has supported the AECF since 2011 and have support 4 of AECF’s windows including the REACT Tanzania, Post Conflict, Africa Agribusiness and Tanzania Agribusiness windows and AECF Connect.\xa0The overarching objective of Swedish aid is to create preconditions for better living conditions for people - women and men -\xa0 living in poverty and under oppression. This is broken down into 6 sub objectives, including better opportunities for people living in poverty to contribute to and benefit from economic growth and obtain a good education; better environment, limited climate impact and greater resilience to environmental impact, climate change and natural disasters. SIDA has three thematic priorities i.e.\xa0democracy and human rights;\xa0environment and climate;\xa0and gender equality and the role of women in development.',
#        'The Netherlands Ministry of Foreign Affairs has supported the AECF since 2008 and have support the General Window and REACT Mozambique windows.\xa0The Netherlands has four development priorities including: security and the rule of law; water management; food security; sexual and reproductive health and rights. Crosscutting themes include women equality and climate change. Economic growth is an important weapon in the fight against poverty and hunger in developing countries. The government therefore encourages these countries to develop their private sectors.',
#        'The United Kingdom’s Department of International Development (DFID) is a founding member of the AECF. AECF has scored an A in all DFID annual reviews since 2012.\xa0They support 6 of AECF’s 8 windows, this includes the General Window, \xa0Africa Agribusiness Tanzania, South Sudan, REACT East Africa regional, Tanzania and Kenya, and Research into Business windows. Economic development through investments in the private sector is a priority for DFID.',
#        'DFID sees the AECF as one of the most successful existing challenge funds that is popular with businesses and other funding partners. The AECF also aligns with DFID’s strategies on scaling up commercial agriculture and improving quality for women in business.',
#        'AECF staff are instrumental in the work that we do to ensure a prosperous and enterprising rural Africa. AECF offers you an opportunity to be part of the team impacting the lives of millions of rural poor across Africa through the over 266 investments it has made in private sector that have resulted in job creation, improved livelihoods, improved health and reduce emissions.',
#        'As a staff member, you will join a team of professionals from across Africa, who are dedicated, dynamic and passionate about the work they do.',
#        "AECF is seeking to hire a security provider to support its operations in Africa. The consultant will conduct a security assessment of AECF's operations, develop a secutiy operational manual, develop country specific security plans, provide security briefings and train AECF staff. Interested companies with experince in providing similar services are urged to apply.",
#        "AECF is looking for a Portfolio Management Director to lead the management of the organisation's core portfolio. We are looking for someone with 7 - +10 years of work experience with private sector, portfolio management, senior leadership and SME engagement. The Director will be a member of AECF Executive Committtee and a key member of the senior management team.",
#        "AECF is looking for a Portfolio Management Director to lead the management of the organisation's core portfolio. We are looking for someone with 7 - +10 years of work experience with private sector, portfolio management, senior leadership and SME engagement. The Director will be a member of AECF Executive Committtee and a key member of the senior management team.",
#        "AECF is seeking to hire a security provider to support its operations in Africa. The consultant will conduct a security assessment of AECF's operations, develop a secutiy operational manual, develop country specific security plans, provide security briefings and train AECF staff. Interested companies with experince in providing similar services are urged to apply.",
#        'AECF recognises that in order to achieve the sustainable development goals number 2, 5, 7 and 13 on ending hunger, achieving gender equality and ensuring access to sustainable clean energy\xa0is not only pertinent, but urgent to address the social norms and cultural practices that hinder women’s meaningful economic participation in the economy.',
#        'As Africa looks to meet the Sustainable Development Goals by 2030, the full participation of women as producers, consumers, business owners and key decision-makers can be a potent force for change.',
#        'As part of our commitment to addressing gender inequalities through market-based approaches, AECF has designed a specific initiative called Investing in Women\xa0which will fund competitions with a special bias towards investments in women-owned/led small- medium enterprises and companies that make significant contributions to reducing the gender gap.',
#        'Investing in Women\xa0is a US $50 million fund with initial funding of £4.95 million from United Kingdom. The fund will be piloted in\xa0selected agriculture value chains in Ethiopia, Sierra Leone, Cote d’Ivoire and Burkina Faso in August\xa02018.',
#        'The Investing in Women initiative will seek to create more gender inclusive agricultural value chains in order to address rural poverty, food insecurity and gender inequality by increasing the proportion of women generating income from agribusiness as well as the number and quality of jobs for women working in agricultural value chains.',
#        'O AECF é uma instituição de desenvolvimento que apoia as empresas na inovação, na criação de empregos e na alavancagem dos investimentos e mercados num esforço para criar resiliência e rendimentos sustentáveis nas comunidades rurais e marginalizadas em África.\n\n',
#        'A agricultura e o agronegócio contabilizam 32 por cento do PIB na África Subsaariana e empregam 65 por cent\n\n\n....',
#        'A janela «Energias Renováveis e Adaptação às Tecnologias Climáticas (REACT)», demonstra como as tecnologias\n\n\n....',
#        'In West Africa, Burkina Faso occupies an important role in the emergence of a regional electricity market linking the Sahel to Ivory Coast and Ghana. Despite this the country has a national electricity access rate of 18.8%. With this recognition the REACT - Efficient Electrification Project \xa0was designed.\xa0',
#        'REACT EEP is a partnership between the Ministry of Energy and the AECF, funded by Swedish Embassy in Burkina Faso. This partnership is as a result of a request made by the Ministry of energy to Swedish Embassy in Burkina Faso to support installation of Solar PV systems to households and SMEs in the urban and peri urban of Ouagadougou.\xa0',
#        'This is a two-year pilot project worth US $5 million that will provide an opportunity for households and Small and Medium Enterprises (SMEs) to access solar energy as primary or back up installations. This will complement electricity supply capacity in Ouagadougou, in order to enable increased energy supply to the large industry and increase rural access to electricity for the development of the local economy. \xa0The subsidy that will be provided to households is 70% and for SMEs, 30% PMI for the acquisition of equipment.\xa0',
#        'Annually, Burkina Faso receives about 3,000 to 3,500 hours of peak sunshine and this has the potential to generate an average of 5.5 kWh/m2 per day, by the standards of a tropical country where solar irradiation is generally high, this solar potential is quite high. According to the Europe Union decentralized off-grid, primarily solar, would be the optimal solution for 65% of households without access in Burkina Faso.\xa0',
#        'In addition to the generation potential, Solar PV systems are already being deployed to meet a wide range of household needs including basic lighting and powering small loads like radios and phone charging. Other bigger systems can power systems for refrigeration, water pumping, televisions and communication equipment and acting as the critical enabler to the emergence of small and micro industries in urban, peri urban and rural Burkina Faso.\xa0',
#        'The Government of Burkina Faso has enacted a law the aims to open up the renewable energy sector to independent producers, and this has provided a boost to PV Investments in the country, especially when it comes to importing solar products.\xa0',
#        'Renewable Energy and Adaptation to Climate Technologies (REACT) window is demonstrating how renewable energy technologies and businesses have the potential to reach Africa’s rural communities. Limited access to sources of energy, (especially in rural areas) continues to undermine the productivity of households and businesses, limit growth, experience high emissions and deteriorating living standards. Climate change has the potential to reduce agricultural yields, increase water scarcity and the frequency of extreme weather. REACT has shown that private sector innovation has the potential to reach people in ways that large-scale government investment in grid extension and climate adaptation infrastructure struggle to deliver.',
#        'In six years, REACT is worth US $161\xa0million of investors commitment and invested in 77 companies implementing innovative business models that provide increased access to clean energy, financial services and climate smart solutions for the rural poor across sub Saharan Africa.\xa0',
#        'Bamako, Mali 27 septembre 2018: Aujourd’hui, la Africa Enterprise Challenge Fund (AECF) a lancé à Bamako, au Mali, le concours Énergie Renouvelable et Adaptation au Changement Climatiques - Afrique\n\n',
#        'Monrovia, Liberia, September 24th, 2018: The Africa Enterprise Challenge Fund (AECF), with support from the Embassy of Sweden,\xa0 today launched the Renewable Energy and Adaptat\n\n',
#        'Ouagadougou, Burkina Faso, August 31st, 2018:  Today, The Africa Enterprise Challenge Fund (AECF)\xa0 with financial support from the Swedish Embassy in Burkina Faso, launched th\n\n',
#        'Ouagadougou, Burkina Faso, July 30th, 2018: With \xa0financial support from the Swedish Embassy in Ouagadougou, The Ministry of Energy of Burkina Faso \xa0in collaboration &nbs\n\n',
#        'The Africa Enterprise Challenge Fund (AECF) has committed to invest more than US$ 300 million (KES 30 billion) in the next three years to support businesses in the renewable energy and agribusiness\n\n',
#        "Monrovia, Libéria, 24 septembre 2018: L'Africa Enterprise Challenge Fund (AECF), avec le soutien de l'ambassade de Suède, a lancé aujourd'hui le concours REACT SSA (énergies renouv\n\n",
#        'Monróvia, Libéria, 24 de Setembro de 2018: O Fundo de Promoção de Empresas Africanas (AECF), com o apoio da Embaixada da Suécia, lançou hoje a competição Energias Renováveis e Adap\n\n',
#        'Bamako, Mali, 27 de Setembro de 2018: O Fundo de Promoção de Empresas Africanas (AECF), lançou em Bamako, Mali, a competição Energias Renováveis e Adaptação às Tecnologias Climátic\n\n',
#        'Bamako, Mali 27 septembre 2018: Aujourd’hui, la Africa Enterprise Challenge Fund (AECF) a lancé à Bamako, au Mali, le concours Énergie Renouvelable et Adaptation au Changement Climatiques - Afrique\n\n',
#        'Bamako, Mali 27 septembre 2018: Aujourd’hui, la Africa Enterprise Challenge Fund (AECF) a lancé à Bamako, au Mali, le concours Énergie Renouvelable et Adaptation au Changement Climatiques - Afrique\n\n',
#        'Monrovia, Liberia, September 24th, 2018: The Africa Enterprise Challenge Fund (AECF), with support from the Embassy of Sweden,\xa0 today launched the Renewable Energy and Adaptat\n\n',
#        "L'Africa Enterprise Challenge Fund (AECF) s'est engagé à investir plus de US $ 300 millions (30 milliards KES) dans les trois prochaines années pour soutenir les entreprises des secteurs des énergi\n\n",
#        'Sweden International Development Cooperation Agency (Sida) and AECF signed a five year agreement worth 400 million SEK (US $48 million) to fund the Renewable Energy and Adaptation to Climate \n\n',
#        'Sweden International Development Cooperation Agency (Sida) and AECF signed a five year agreement worth 400 million SEK (US $48 million) to fund the Renewable Energy and Adaptation to Climate \n\n',
#        'About 510 million people in sub-Saharan Africa (SSA) currently have no access to electricity and will not get grid access in the foreseeable future, resulting in a steady increase in the number of people without electricity until at least 2025.\xa0',
#        'The slow progress and high cost of conventional solutions to the household energy crisis means that cheaper and more accessible new clean technologies offer a better chance of improved access to energy for rural households in the foreseeable future. Over the last decade, clean energy technologies have become more economical than conventional generation for many applications, and the regulatory environment to facilitate their application has improved. Risk and market failures restrict innovation and prevent the development and use of successful business models and technologies.\xa0',
#        "The AECF's engagement in the energy sector under REACT SSA is designed to catalyze the private sector to increase supply of cleaner fuels,\xa0raise awareness of the dangers from indoor air pollution,\xa0demonstrate how new knowledge in renewable energy technologies can be put into practice in ways that benefit the poor\xa0especially women, provide evidence on challenges in policy formulation and implementation\xa0",
#        'The target countries include\xa0Burkina Faso,\xa0Ethiopia,\xa0Kenya,\xa0Liberia,\xa0Mali,\xa0Mozambique,\xa0Zimbabwe,\xa0Sudan and\xa0Somalia',
#        'The REACT SSA competition is open to private sector enterprises with relevant renewable energy businesses in one or more of the seven\xa0participating countries.To Apply please click on the country of interest below',
#        'AECF REACT Sub-Saharan Africa (SSA) Mozambique competition is now receiving applications, from 14th September 2018 to 9th November 2018.',
#        'To start your application click on the apply button, for more information on the competition download the term sheet provided or email us on react@aecfafrica.org with a copy to Lucinda Tyser on Ltyser@aecfafrica.org',
#        'AECF REACT Sub-Saharan Africa (SSA) Liberia competition is now receiving applications, from 24th September 2018 to 19th November 2018.',
#        'To start your application click on the apply button, for more information on the competition download the term sheet provided or email us on react@aecfafrica.org with a copy to natino@aecfafrica.org and eobiero@aecfafrica.org',
#        'Les candidatures pour la compétition REACT Africa subsaharienne au Mali sont ouvert à partir 27 septembre 2018 jusqu’au 22 novembre 2018.',
#        'Pour commencer votre candidature, appuyer sur le bouton <<apply>>. Pour plus d’informations sur la compétition, téléchargez les conditions de candidature ou envoyez un email à\xa0react@aecfafrica.org\xa0en mettant un copie\xa0:\xa0EObiero@aecfafrica.org',
#        'AECF Connect is a pilot initiative funded by SIDA to support\xa0AECF investees in raising capital from investors and lenders to extend project impact by ensuring continued financial support from other investors.',
#        'From the competition stage to project completion, AECF Connect supports investees to enable them identify new sources of\xa0commercial capital. AECF Connect:',
#        'AECF Connect enhances the AECF’s position as a feeder fund for other investors, by not only providing capital to initiate projects but also leveraging more private sector capital into these projects over time. This enables\xa0AECF to demonstrate an increased return on its grants and loans programme. To date, AECF Connect\xa0has leveraged more than US $36 million.\xa0',
#        'With funding from SIDA, AECF Connect has expanded Funding Partners’ outreach and impact through the most “investment ready” companies in our 266 investee portfolio. The goal of having scale across Africa can only be achieved by working in partnership with other investors and Funding Partners, ensuring that the AECF selects business likely to be of interest to them and helping projects in the portfolio connect with these investors in a meaningful way.',
#        'If you would like to work with us or would like to make an inquiry, please contact us on email:\xa0info@aecfafrica.org',
#        'AECF believes that the private sector offers huge potential for economic growth, employment and income generation tha\n\n\n...',
#        'AECF accelerates access to affordable off-grid energy by providing financial and technical assistance to innovative a\n\n\n...',
#        'Investing in women pays dividends since women invest 90% of their earnings on food, health and education for the hous\n\n\n...',
#        'The\xa0AECF Conference 2018, is currently being held at Villa Rosa Kempinski,\xa0Nairobi, Kenya, under the theme,\xa0“\n\n\n...',
#        'The AECF measures its contribution to improving the lives of the poor primarily through increased income and wages from new jobs, supported by other sector-specific metrics. Our investees benefit from the high incomes generated or cost savings for smallholder farmers and other individuals from the products that they supply or the goods they buy. Moving forward, The AECF is becoming more inclusive to reflect the increasing importance of the social impacts of its work and the priorities established by the Sustainable Development Goals on gender equality, decent work and the environment.',
#        'The AECF is a development institution which supports businesses to innovate, create jobs, leverage investments and markets in an effort to\xa0create resilience and sustainable incomes in rural and marginalized communities in Africa. Launched in 2008, the AECF has mobilized over US $356 million to date, leveraging more than US $658 million in matching capital and improving the lives of more than 16 million people in 2017 alone through jobs and increased household incomes. AECF has so far supported 266 companies in 25 countries in sub-Saharan Africa across 40 value chains in our focal sectors of agribusiness and renewable energy.',
#        'In the new 2018-2020 strategy, our goal is to “double our impact in half the time”. To achieve this, we will continue to focus on the agribusiness and renewable energy sectors, increase support to climate smart technologies, refine our challenge model, expand regional presence, deepen focus on gender, youth and employment by expanding our products and partnership approach to better meet our investees’ current needs; and ensure they rapidly scale and transition to external financing and sustainability thereby attaining our vision of ‘A Prosperous and Enterprising Rural Africa’'],
#       dtype='<U1042')

# %%
database
# Out:
#                                           Organisation  \
# 1          The Africa Enterprise Challenge Fund (AECF)
# 2     Alliance for a green revolution in Africa (AGRA)
# 3                               Global Innovation Fund
# 4                                          Acumen Fund
# 5                                       Bamboo Finance
# 6                             African Development Fund
# 7                                        Willow Impact
# 8                    Vista Ventures Social Impact Fund
# 9                                   Grayghost ventures
# 10   Business/Partners Investing in Entrepreneurs (...
# 11                 LGT Venture Philanthropy Foundation
# 12                                              Grofin
# 13                                Invested Development
# 14                Investisseurs &\r\nPartenaires (I&P)
# 15                                            Novastar
# 16                                          Oikocredit
# 17                           Persistent Energy Capital
# 18              Social Venture Capital\r\nFund (SOVEC)
# 19                                    Terra Bella Fund
# 20                     African Development Bank (AfDB)
# 21                                       CDC Group plc
# 22                      European Investment Bank (EIB)
# 23      Netherlands Development Finance Company  (FMO)
# 24                                Norwegian Investment
# 27                                            Proparco
# 28   The Swiss Investment Fund for Emerging Markets...
# 29             International Finance Corporation (IFC)
# 30                                       Credit Suisse
# 31                                JP Morgan Chase & Co
# 32                   Bill and Melinda Gates Foundation
# ..                                                 ...
# 78                 Social Venture Capital Fund (SOVEC)
# 79                                          Symbiotics
# 80                  Terra Global Investment Management
# 81    The Investment Fund For         Health In Africa
# 82                                    Treetops Capital
# 83                       Triodos Investment Management
# 84                                      UFF Management
# 85   Unique Venture Capital (UVC) Management Compan...
# 86                                       Vital Capital
# 87                             Willow Impact Investors
# 88                         Yunus Social Business (YSB)
# 89                                     The BiD Network
# 90                 Dalberg Global Development Advisors
# 91                                   Enclude Solutions
# 92                                     Endeavor Global
# 93                                    Impact Amplifier
# 94                           LifeCo UnLtd South Africa
# 95                               Open Capital Advisors
# 96                                    Shell Foundation
# 97              Social Enterprise Academy South Africa
# 98                                         Technoserve
# 99                                   Bertha Centre for
# 104               Lagos Business School (LBS), Nigeria
# 105            Strathmore Business School (SBS), Kenya
# 106                       Aspen Network of Development
# 108             Global Impact Investing Network (GIIN)
# 109  Southern African Impact Investing Network (SAIIN)
# 110      Global Impact Investing Rating System (GIIRS)
# 116               Global Alliance for Clean Cookstoves
# 117                  Draper Richards Kaplan Foundation
#
#                                                Website
# 1                           http://www.aecfafrica.org/
# 2                              http://agra.org/grants/
# 3                     http://www.globalinnovation.fund
# 4                                   http://acumen.org/
# 5                             http://www.bamboocp.com/
# 6    http://www.afdb.org/en/about-us/corporate-info...
# 7                         http://www.willowimpact.com/
# 8                        http://www.vistaventures.com/
# 9         http://www.grayghostventures.com/indexa.html
# 10                      http://businesspartners.co.ke/
# 11                           https://www.lgtvp.com/en/
# 12                               http://www.grofin.com
# 13                     http://investeddevelopment.com/
# 14        http://www.ietp.com/en/content/entrepreneurs
# 15                    http://www.novastarventures.com/
# 16                     https://www.oikocredit.org.uk/t
# 17                        http://www.persistentnrg.com
# 18                                        www.sovec.nl
# 19   http://www.terraglobalcapital.com/terra-bella-...
# 20                                        www.afdb.org
# 21                                    www.cdcgroup.com
# 22                           http://www.eib.europa.eu/
# 23                                  http://www.fmo.nl/
# 24                              http://www.norfund.no/
# 27   http://www.proparco.fr/site/proparco/Accueil_P...
# 28                                http://www.sifem.ch/
# 29                                  http://www.ifc.org
# 30                           https://www.credit-suisse
# 31                          http://www. jpmorganchase.
# 32                     http://www.gatesfoundation.org/
# ..                                                 ...
# 78                                        www.sovec.nl
# 79                             www.symbioticsgroup.com
# 80                         www.terraglobalcapital. com
# 81                                    www.ifhafund.com
# 82                             www.treetopscapital.com
# 83           www.triodos.com/en/ investment-management
# 84                                       www.uff.co.za
# 85                                       www.uvcmc.com
# 86                       http://www.vital-capital.com/
# 87                                www.willowimpact.com
# 88                                     www.yunussb.com
# 89                                  www.bidnetwork.org
# 90                              http://www.dalberg.com
# 91                            www.encludesolutions.com
# 92                            http://www.endeavor.org/
# 93                   http://www.impactamplifier.co.za/
# 94                    http://www.unltdsouthafrica.org/
# 95                     http://opencapitaladvisors.com/
# 96                             www.shellfoundation.org
# 97                          http://www.sea-africa.org/
# 98                          http://www.technoserve.org
# 99               http://www.gsb.uct. ac.za/s.asp?p=389
# 104                             http://www.lbs.edu.ng/
# 105                    http://www.sbs. strathmore.edu/
# 106                             www.aspeninstitute.org
# 108                             http://www.thegiin.org
# 109                            http://www.saiin.co.za/
# 110              http://b-analytics.net/ giirs-ratings
# 116                        http://cleancookstoves.org/
# 117                     https://www.drkfoundation.org/
#
# [102 rows x 2 columns]

# %%
class InvestorCrawler():
    def __init__(self):

# %%
class Searcher():
    def __init__(self):
        # prepare string cleaner
        # store stop words
        self.stop_words = stop_words.get_stop_words("en")
        # prepare stemmer
        self.stemmer = PorterStemmer()
        
        # get and process database
        try:
            self._database = pd.read_csv('crawled_database.csv').iloc[:, [1, 2, 3]]
            print("load crawled database successful")
        except:
            # if no crawled database given
            # load the dataset : including only each company's name, url and summary
            print('fail to load crawled database')
            self._database = pd.read_csv("../input/InvestData_2017-Nov-22_0101.csv").iloc[:, [1, 5, 6]]
            self.crawl_database()
        self.process_database()
    
    def clean_string(self, string):
        """
        Clean input string by 
        1. removing all non alphabet letters
        2. removing all stop-words
        2. stemming all tokens
        """
        # remove non alphabet numbers
        string = re.sub("[^a-z]*", '', string.lower())
        
        # stem the string
        string = self.stemmer.stem_sentence(string)
        
        # remove stop words
        string = "".join([token if token not in self.stop_words for token in string.split()])
        
        return string
        
    def process_database(self):
        # 1: company name, 5: company website, 6: company manual desc
        raw_texts = []
        # preprocess all the text data and remove any row without any useful data, and segment each word
        drop_list = []
        for row in self._database.itertuples():
            if not type(row[1]) is str or (not type(row[2]) is str and not type(row[3]) is str):
                # check if the row has data
                drop_list.append(row[0])
            else:
                # process text data of both manually summarized or crawled data
                tmp_text = []
                for col in [2, 3]:
                    real_col = col - 1
                    text = row[col]
                    if type(text) is str:
                        text = self.word_tokenize_string(text)
                        self._database.iloc[row[0], real_col] = text
                        tmp_text.append(text)
                # merge texts of same company
                tmp_text = '    '.join(tmp_text)
                raw_texts.append(tmp_text)
                
        # drop all the rows that do not have essential data
        self._database.drop(drop_list, inplace=True)
        # create similarity col for similarity search use
        self._database = self._database.assign(similarity=np.zeros(len(self._database)))
        
        # use the raw_texts to generate tfidf model
        self._tfidf, self._dictionary = self.get_tfidf_and_dictionary(raw_texts)
        
    def crawl_database(self):
        for row in self._database.itertuples():
            if not (not type(row[1]) is str or (not type(row[2]) is str and not type(row[3]) is str)):
                # process each website and replace web address with texts crawled
                url = row[2]
                texts = self.get_text_from_url_and_its_children(url)
                if not texts:
                    # if cannot access url, replace url with Nan
                    self._database.iloc[row[0], 1] = np.nan
                else:
                    # replace the url with the crawled texts
                    texts = '   '.join(texts)
                    self._database.iloc[row[0], 1] = texts
        
    def save_database(self):
        self._database.to_csv('crawled_database.csv')
        print("database save successful")
    
    def update_similarity(self, input_text, col=2):
        # get input text vector
        input_text_vector = self.get_doc_vector(input_text)
        i = 0
        for row in self._database.itertuples():
            row_text_vector = self.get_doc_vector(row[col])
            similarity = input_text_vector.dot(row_text_vector)
            self._database.iloc[i, -1] = similarity
            i += 1
        self._database = self._database.sort_values(by='similarity', ascending=False)
        return self._database

    def get_doc_vector(self, text):
        if not text == text:
            return self._w2v['happy'] * 0
        tokens = list(self._dictionary.token2id)
        # convert any unknown word to known word
        new_text = []
        for word in text.split():
            if word in tokens:
                new_text.append(word)
            elif word in w2v: # replace the unknow word with the most similar word in tokens of dictionary
                new_text.append(self._w2v.most_similar_to_given(word_list=tokens, w1=word))

        # start to calculate vector using tfidf weighted word vector sum
        # get tfidf weight
        tokenized_text = [self._dictionary.doc2bow(new_text)]
        tfidf_text = self._tfidf[tokenized_text][0]
        # sum weighted word vectors
        sum_vector = self._w2v['happy'] * 0 # get the size of the word vector
        for word_id, weight in tfidf_text:
            word = self._dictionary[word_id]
            sum_vector += self._w2v[word] * weight
        if sum_vector.any():
            sum_vector /= np.sqrt(sum_vector.dot(sum_vector)) # normalize the vector
            
        return sum_vector
    
    def word_tokenize_string(self, text):
        stop_words = get_stop_words('en') # get too frequent word
        text = text.replace('\r', ' ').replace('\n', ' ') # remove symbols
        text = re.sub(r"http\S+", "", text) # remove urls
        # remove any word that present too frequently or cannot be converted to word vector
        text = [word for sent in sent_tokenize(text.lower()) for word in word_tokenize(sent) \
                if not word in stop_words and word in self._w2v]
        return ' '.join(text)
    
    @staticmethod
    def get_tfidf_and_dictionary(texts):
        # get dictionary of texts
        texts = [text.split() for text in texts]
        dictionary = corpora.Dictionary(texts)

        # get tfidf ranking model
        tokenized_texts = [dictionary.doc2bow(text) for text in texts]
        tfidf = models.TfidfModel(tokenized_texts)

        return tfidf, dictionary
    
    def get_text_from_url_and_its_children(self, main_url):
        print("starting to crawl main url: ", main_url)
        # check validity of main_url
        resp = url_is_valid(main_url)
        if not resp:
            print("main_url is not valid")
            return False

        print("\nstarting to crawl all its children")
        # grab all urls in this web page
        urls = [main_url]
        urls.extend(get_urls_from_url(main_url))
        urls = list(set(urls)) # remove duplicated urls
        print("\n\nthese are the children links we crawled")
        print(urls, "\n")
        # grab all texts in each urls asynchronously
        # argmumentize urls
        urls = [(url, main_url) for url in urls]
        with multiprocessing.Pool(processes=24) as pool:
            text_data = pool.starmap(get_text_from_url_with_check, urls) 
            # try terminating hung jobs
        text_data = [text for text in text_data if len(text_data) > 0] # remove empty returns
        text_data = [text for text_list in text_data for text in text_list] # get list elements to str
        return text_data
# Out:
#   File "<ipython-input-5-1cc40a161c8c>", line 35
#     string = "".join([token if token not in self.stop_words for token in string.split()])
#                                                               ^
# SyntaxError: invalid syntax

# %%
searcher = Searcher(w2v=w2v)
# there might be main_url + url is not valid, because url and main_url has overlaps, or main_url is not the root
# must provide root url, or 
# use overlaps to do intelligent main_url + url
# Out:
# load crawled database successful

# %%
input_text = "new start up aiming at low income customers, dedicated in green energy"

# %%
# %time searcher.update_similarity(input_text, col=2)
# Out:
# CPU times: user 47.2 s, sys: 26.3 ms, total: 47.3 s
# Wall time: 47.3 s
#                                           Organisation  \
# 94                                         Technoserve
# 35                              Rockefeller Foundation
# 86                 Dalberg Global Development Advisors
# 1     Alliance for a green revolution in Africa (AGRA)
# 14                                            Novastar
# 100  Southern African Impact Investing Network (SAIIN)
# 89                                    Impact Amplifier
# 22      Netherlands Development Finance Company  (FMO)
# 6                                        Willow Impact
# 10                 LGT Venture Philanthropy Foundation
# 3                                          Acumen Fund
# 9    Business/Partners Investing in Entrepreneurs (...
# 103                  Draper Richards Kaplan Foundation
# 30                   Bill and Melinda Gates Foundation
# 0          The Africa Enterprise Challenge Fund (AECF)
# 102               Global Alliance for Clean Cookstoves
# 13                Investisseurs &\r\nPartenaires (I&P)
# 7                    Vista Ventures Social Impact Fund
# 5                             African Development Fund
# 96                Lagos Business School (LBS), Nigeria
# 26   The Swiss Investment Fund for Emerging Markets...
# 60                        Mergence Investment Managers
# 12                                Invested Development
# 8                                   Grayghost ventures
# 4                                       Bamboo Finance
# 82                                       Vital Capital
# 18                                    Terra Bella Fund
# 21                      European Investment Bank (EIB)
# 23                                Norwegian Investment
# 25                                            Proparco
# ..                                                 ...
# 31                                  Calvert Foundation
# 41                                            Agri-Vie
# 29                                JP Morgan Chase & Co
# 28                                       Credit Suisse
# 27             International Finance Corporation (IFC)
# 24                                 Fund for Developing
# 20                                       CDC Group plc
# 19                     African Development Bank (AfDB)
# 17              Social Venture Capital\r\nFund (SOVEC)
# 40                                         Acumen Fund
# 42                                AlphaMundi Group Ltd
# 62                        Microvest Capital Management
# 53                                              GroFin
# 61                             MicroCredit Enterprises
# 16                           Persistent Energy Capital
# 58                   Investisseurs & Partenaires (I&P)
# 57               International Housing Solutions (IHS)
# 56           Injaro Agricultural Capital Holdings Ltd.
# 55                                         Ignite Fund
# 54                                       Heart Capital
# 51                            Grassroots Business Fund
# 43                                       Ariya Capital
# 50                                    Good Capital LLC
# 49                                        Gawa Capital
# 48                                          DOB Equity
# 47                      Developing World Markets (DWM)
# 46                         Catalyst Principal Partners
# 45              BlueOrchard Impact Investment Managers
# 44                                      Bamboo Finance
# 52                           Gray Ghost Ventures (GGV)
#
#                                                Website  \
# 94   job us important one . sign learn can help us ...
# 35   first american red present-day initiatives , r...
# 86   entrepreneurship going create mass-scale jobs ...
# 1    division operates understanding agricultural t...
# 14   amy bell , executive director social finance j...
# 100  move immediately right hand lane , turn right ...
# 89   impact amplifier developed core set services a...
# 22   bank 45 years experience investing private sec...
# 6    trademarks , logos service marks displayed sit...
# 10   venture philanthropy , provide philanthropic c...
# 3    partners changemakers . put money mouths ’ re ...
# 9    know investing , entrepreneur , will help crea...
# 103  look exceptional entrepreneurs seek entreprene...
# 30   work partners worldwide tackle critical proble...
# 0    rt . hon lord boateng barrister , former briti...
# 102  united nations sets inspiring ambition sustain...
# 13   & p conducts every year in-depth impact study ...
# 7    vista ventures social impact fund focuses soci...
# 5    african development bank provided much-needed ...
# 96   content two programmes . programme blended lea...
# 26   can order newsletter – naturally free charge ....
# 60   read video transcript fabian ’ s current think...
# 12   look technologies agriculture let growers beco...
# 8    trademarks , logos service marks displayed sit...
# 4    team includes individuals expertise private eq...
# 82   africa - strengthening communities within work...
# 18   terra bella fund frontier private equity fund ...
# 21   © european investment bank 2018 european inves...
# 23   roland leder folk fra 17 forskjellige på tre ....
# 25   la croissance démographique de l ’ afrique sub...
# ..                                                 ...
# 31                                                 NaN
# 41                                                 NaN
# 29                                                 NaN
# 28                                                 NaN
# 27                                                 NaN
# 24                                                 NaN
# 20                                                 NaN
# 19                                                 NaN
# 17                                                 NaN
# 40                                                 NaN
# 42                                                 NaN
# 62                                                 NaN
# 53                                                 NaN
# 61                                                 NaN
# 16                                                 NaN
# 58                                                 NaN
# 57                                                 NaN
# 56                                                 NaN
# 55                                                 NaN
# 54                                                 NaN
# 51                                                 NaN
# 43                                                 NaN
# 50                                                 NaN
# 49                                                 NaN
# 48                                                 NaN
# 47                                                 NaN
# 46                                                 NaN
# 45                                                 NaN
# 44                                                 NaN
# 52                                                 NaN
#
#                                            Description  similarity
# 94   nonprofit organization develops business solut...    0.878591
# 35   rockefeller foundation pioneering organization...    0.874697
# 86   strategic advisory firm works clients maximise...    0.874492
# 1    agra aims invest projects can measurable impac...    0.873631
# 14   , based nairobi , venture catalyst firm assist...    0.873388
# 100  aims promote concept practice impact investing...    0.873245
# 89   impact amplifier consulting firm works acceler...    0.872664
# 22   entrepreneurial development bank offering fina...    0.872290
# 6    impact investment firm manages advises social ...    0.871983
# 10   seek support non-profit organizations for-prof...    0.870239
# 3    charity organisation providing funding early s...    0.867558
# 9    specialist risk finance company provides custo...    0.867318
# 103  draper richards kaplan foundation global ventu...    0.866841
# 30   gates foundation large global organization ded...    0.862412
# 0    challenge fund aims reduce poverty supporting ...    0.861566
# 102  global alliance clean cookstoves ( alliance ) ...    0.861035
# 13   & p impact investing group dedicated small med...    0.859609
# 7    fund provide education financial support early...    0.858667
# 5    adf contributes promotion economic social deve...    0.858412
# 96   lbs business school hosted university lagos , ...    0.856475
# 26   switzerland . mission promote longterm , susta...    0.855182
# 60   mergence asset management firm offering invest...    0.847612
# 12   invested development impact investment managem...    0.846490
# 8    seeks eliminate poverty strengthen communities...    0.840447
# 4    bamboo finance commercial private equity firm ...    0.839225
# 82   vital capital private equity fund prioritises ...    0.839037
# 18   terra bella fund frontier private equity fund ...    0.812816
# 21   bank european union . primarily supports proje...    0.770395
# 23                                           norwegian    0.692814
# 25   french . invests emerging developing countries...    0.553189
# ..                                                 ...         ...
# 31   calvert foundation community development finan...    0.000000
# 41   private equity investment fund focused food ag...    0.000000
# 29   jp morgan global financial services firm engag...    0.000000
# 28   credit suisse global financial services compan...    0.000000
# 27   ifc makes investments inclusive businesses con...    0.000000
# 24   . invests enterprises low income countries pro...    0.000000
# 20   cdc u.k. ’ s development finance institution ,...    0.000000
# 19   afdb multilateral established contribute econo...    0.000000
# 17   fund invests local entrepreneurs . focus count...    0.000000
# 40   non-profit fund makes investments early-stage ...    0.000000
# 42   impact investing scalable ventures sustainable...    0.000000
# 62   capital management intermediary low-income fin...    0.000000
# 53   sme finance development company offering combi...    0.000000
# 61   unique guarantor model microcredit enterprises...    0.000000
# 16   pec invests incubates businesses commercial ap...    0.000000
# 58   & p impact investing group dedicated small med...    0.000000
# 57   ihs private equity firm focused development re...    0.000000
# 56   makes investments small-and enterprises along ...    0.000000
# 55   ignite fund invests small growing businesses (...    0.000000
# 54   heart capital impact investing company forms s...    0.000000
# 51   hybrid model , partnering businesses provide l...    0.000000
# 43   ariya capital private equity venture capital f...    0.000000
# 50   good capital manages sustainable social enterp...    0.000000
# 49   gawa capital advises two funds – gawa microfin...    0.000000
# 48   dob equity invests growth capital financially ...    0.000000
# 47                     asset manager investment bank .    0.000000
# 46   catalyst principal partners manages eastern pr...    0.000000
# 45   manages microfinance fund invests microfinance...    0.000000
# 44   commercial private equity firm specializing in...    0.000000
# 52   aims serve lowincome communities developing na...    0.000000
#
# [104 rows x 4 columns]

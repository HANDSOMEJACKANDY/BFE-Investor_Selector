# %% [markdown]
# # This note book is a demonstration of how to use *investor_selector_lsi* to index a startup description

# %% [markdown]
# ## First of all, import everything from *investor_selector_lsi*
# ### Make sure *investor_selector_lsi.py* is in the directory

# %%
from investor_selector_lsi import *

# %% [markdown]
# ## Secondly, initiate a *TopicModelIndexer* Object for the indexing
# ### Make sure the *index_models* folder is in the current directory

# %%
ti = TopicModelIndexer(folder_dir="index_models")
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Organisation', 'Website', 'Crawled',
#        'Index'],
#       dtype='object')

# %% [markdown]
# ## Finally, index the database with a fabricated startup description

# %%
input_text = "new start up aiming at low income customers, dedicated in green energy"
ti.index_database(input_text)

# %% [markdown]
# ### Let's display the database.
# ### The Similarity column is the column for input_text's similarity to each investor
# ### The higher, the more relevent the investor is.

# %%
ti.db
# Out:
#      Unnamed: 0  Unnamed: 0.1  \
# 0             0             1
# 1             1             2
# 2             2             3
# 3             3             4
# 4             4             5
# 5             5             6
# 6             6             7
# 7             7             8
# 8             8             9
# 9             9            10
# 10           10            11
# 11           11            12
# 12           12            13
# 13           13            14
# 14           14            15
# 15           15            16
# 16           16            17
# 17           17            18
# 18           18            19
# 19           19            20
# 20           20            21
# 21           21            22
# 22           22            23
# 23           23            24
# 24           24            27
# 25           25            28
# 26           26            29
# 27           27            30
# 28           28            31
# 29           29            32
# ...

# %% [markdown]
# ### Good luck
